# %%
#1.Find the value of T(2) for the recurrence relation T(n) = 3T(n-1) + 12n, given that T(0)=5.

""" Given - 

T(n) = 3T(n-1) + 12n
T(0) = 5 

T(2) = 3T(2-1) + 12* 2 
T(2) = 3T + 24 -----> 1 
    
    
T(1) = 3T(1-1) + 12 * 1 
T(1) = 3T + 12 ------->2 

T(0) = 5 
now, 
T(1) = 15 + 12 = 27 
T(2) = 3 *27 + 24 = 105 

Therefore,the value of T(2) = 105  """

# 2. Given a recurrence relation, solve it using the substitution method:
#a. T(n) = T(n-1) + c

"""
T(n) = T(n-1) + c 
     = T(n-2) + 2c
     = T(n-3) + 3c 
     = ...
     
T(n) = c + (n-1)c = nc

"""
#b. T(n) = 2T(n/2) + n

""" 
T(n) = 2T(n/2)+n
    = 2[2T(n/4) + n/2 ] + n
    = 2^2T(n/2^2) + 2n 

    T(n) =  2 ^log2n T(1) + nlog2n = n+ n log2n

"""
#c. T(n) = 2T(n/2) + c
""" 

T(n) = 2T (n/2) + c 
     = 2[2T (n/4) + c] + c
     
     
     = 2 ^ log2nT(1) + clog2n = n + clog2n 
     
     = o(n + clogn)"""
#d. T(n) = T(n/2) + c
"""
T(n) = T(n/2) + c 
     = T(n/2^2) + 2 c 
     
     
     = T(1) + clog2n = clog2n
     = 0(logn)"""

#3.. Given a recurrence relation, solve it using the recursive tree approach:
# a. T(n) = 2T(n-1) +1
"""
T(n)
│
├── T(n-1)
│   ├── T(n-2)
│   │   ├── ...
│   │
│   ├── T(n-2)
│   │   ├── ...
│   │
│   └── 1
│
└── 1

T(n) = o(n)

"""
# b. T(n) = 2T(n/2) + n
"""

T(n)
│
├── T(n/2)
│   ├── T(n/4)
│   │   ├── ...
│   │
│   ├── T(n/4)
│   │   ├── ...
│   │
│   └── n/2
│
└── n


T(n) = O(nlogn )
"""
