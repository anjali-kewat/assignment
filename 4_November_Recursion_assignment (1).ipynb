# %%
#1. Can you explain the logic and working of the Tower of Hanoi algorithm by writing a Java program? How does the recursion work, and how are the movements of disks between rods accomplished?
def tower_of_hanoi(n, source, target, auxiliary):
    if n == 1:
        print(f"Move disk 1 from {source} to {target}")
        return
    tower_of_hanoi(n-1, source, auxiliary, target)
    print(f"Move disk {n} from {source} to {target}")
    tower_of_hanoi(n-1, auxiliary, target, source)

# Example usage
num_disks = 3
tower_of_hanoi(num_disks, 'A', 'C', 'B')

#logic
""" 
1.The tower of hanoi function is a recursive function that take four parameters:
n - the number of disk to move 
source - the rod from which to move the disks.
target - the rod which the disks should be removed .
auxiliary - the auxialiary rod that can be used during the  movement .

2.The base case is when there is only one disk .it directly,moves the disk from the source rod to the target rod.

3.In the recursive case ,the function follows these steps:
-Move n-1 disks from the source rod to the auxiliary rod using the target rod as the auxiliary.
-Move the remaining disks from the source rod to the target rod.
-Move the n-1 disks from the auxiliary rod to the targert rod using the source rod as the auxiliary.
"""



#2.  Given two strings word1 and word2, return the minimum number of operations required to convert word1 to word2.
def minDistance(word1,word2):
    m,n = len(word1),len(word2)

    dp = [[0] * (n+1) for _ in range(m+1)]

    for i in range(m+1):
        dp[i][0] = i 
    for j in range(n+1):
        dp[0][j] = j 

    for i in range(1,m+1):
        for j in range(1,n+1):
            if word1[i-1] == word2[j-1]:
                dp[i][j] = dp[i-1][j-1]

            else:
                dp[i][j] = 1 + min(dp[i-1][j],dp[i][j-1],dp[i-1][j-1])

    return dp[m][n]

word1 = "horse"
word2 = "ros"
result = minDistance(word1,word2)
print(result)
word3 = "intention"
word4 = "execution"
result1 = minDistance(word3,word4)
print(result1)

#3. Print the max value of the array [ 13, 1, -3, 22, 5]

def find_max_recursive(arr,index):
     #base case condition 
    if index == len(arr)-1:
        return arr[index]
    
    max_in_rest = find_max_recursive(arr,index+1)

    return max(max_in_rest,arr[index])

arr = [13,1,-3,22,5]
result = find_max_recursive(arr,0)
print(result)

#4.Find the sum of the values of the array [92, 23, 15, -20, 10]

def sum_values_recursive(arr,index):

    #base condition 
    if index == len(arr)-1 :
        return arr[index]
    
    sum = sum_values_recursive(arr,index + 1)

    return arr[index] + sum

arr = [9,23,15,-20,10]
result = sum_values_recursive(arr,0)
print(result)

#5.
def count_digits(n):
    if n<10:
        return 1 
    
    return 1 + count_digits(n//10)

def is_armstrong_recursive(n):
    if n<10:
        return True
    
    num_digits = count_digits(n)

    armstrong_sum = sum(int(digit) ** num_digits for digit in str(n))

    return armstrong_sum == n 

input = 153
result = is_armstrong_recursive(input)
print("Output :","Yes" if result else "no")

input1 = 123
result1 = is_armstrong_recursive(input1)
print("Output 2:","Yes" if result1 else "No")
# Out:
# Move disk 1 from A to C
# Move disk 2 from A to B
# Move disk 1 from C to B
# Move disk 3 from A to C
# Move disk 1 from B to A
# Move disk 2 from B to C
# Move disk 1 from A to C
# 3
# 5
# 22
# 37
# Output : Yes
# Output 2: No
