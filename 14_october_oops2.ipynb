# %%
##CONSTRUCTOR

#1. What is a constructor in Python? Explain its purpose and usage.

""" A constructor is a special method within a class that is automatically called when an object of that class is created.THe purpose of a constructor is to initialize the attribute or properties of the object.
Purpose --->
- The primary purpose is to set initial value for the attribute of the object.
-It allows you to assign values to instance variables based on the arguments provided during object creation.

Usage --->
- It takes self as its first parameter and can take additional parameters to set initial values for attributes.
-The constructor is automatically called when an object is created.
-It allows you to customize the initialization process for each object.You can pass different values as arguments during object creation to  create objects with distinct initial states."""
#2. Differentiate between a parameterless constructor and a parameterized constructor in Python.
""" Parameterless --->
-It does not take any parameters.It is defines without any input parameters.
-It intializes the object with default values .

Parameterized constructor --->
-It takes one or more parameters.
-It allows you to pass values during object instantiation .
-It facilitates customization ."""


#3. How do you define a constructor in a Python class? Provide an example.

'''class Person:
    def __init__(self,name,age):
        self.name = name 
        self.age = age 

person1 = Person("arru",34)
print(person1.name)
#4. Explain the `__init__` method in Python and its role in constructors.

""" The name __init__ stands for initialize and it is automatically called when an object of the class is created.
role-
- The __init__ method is the constructor of the class.It plays a crucial role in setting up the initial state of an object.
-It allows you to customize the initialization process by accepting parameters and using them to set the initial values of the object's attributes."""
#5. In a class named `Person`, create a constructor that initializes the `name` and `age` attributes. Provide an example of creating an object of this class.

class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age

person2 = Person("Agni",23)
print(person2.age)
#6. How can you call a constructor explicitly in Python? Give an example.

class Myclass:
    def __init__(self,value):
        self.value = value 
    
    def custom_initialization(self,new_value):
        print("performing custom initialization")
        self.value = new_value

obj = Myclass(10)
print(obj.value)

obj.custom_initialization(20)
print(obj.value)
#7. What is the significance of the `self` parameter in Python constructors? Explain with an example.

""" Self parameter in a constructor is a  reference to the instance of the class .
It is a convention ,not a keyword ,and you can choose any name for this parameter,but self is widely used and considered good practice.
"""

class computer:
    def __init__(self,computername):
        self.computername = computername

comp1 = computer("laptop")
print(comp1.computername)
#8. Discuss the concept of default constructors in Python. When are they used?

""" Default constructor refers to the constructor that is automatically provided by pythom if a class does not explicitly define one .

Uses --
- Default constructors are useful when you want to create instances of a class without needing to provide any initializes value explicitly"""

class Myclass:
    pass

obj1 = Myclass()
#9. Create a Python class called `Rectangle` with a constructor that initializes the `width` and `height` attributes. Provide a method to calculate the area of the rectangle.

class Rectangle:
    def __init__(self,width,height):
        self.width = width
        self.height = height

    def area_of_rec(self):
        area = (self.width *self.height)
        return f"Area of rectangle : {area}"
rec = Rectangle(4,6)
print(rec.area_of_rec())
#10. How can you have multiple constructors in a Python class? Explain with an example.

""" A class typically has a single constructor ,the __init__ method .
However, you can achieve a similar effect to having multiple constructors by using default parameter values or by using class methods.
"""

class rectangle:
    def __init__(self,width =None,height =None):
        self.width =width
        self.height =height
    
    def calculate_area(self):
        if self.width is not None and self.height is not None:
            return self.width *self.height
        else:
            return "width and height must be provided to calculate area."

rec2 = rectangle(6,8)
area1 = rec2.calculate_area()
print(f"Area of rectangle : {area1}") 
#11. What is method overloading, and how is it related to constructors in Python?

"""Overloading - It refers to the ability to define multiple methods in a class with the same name  but  different parameter lists .
It provides an alternative way to instantiate object with a simplified parameter list ."""
#12. Explain the use of the `super()` function in Python constructors. Provide an example.

"""Super() function -- It is used to call a method from a parent class.
It is often used to invoke the constructors of the parent class within the constructor of a subclass."""

class parentclass:
    def __init__(self,param1,param2):
        self.param1 = param1
        self.param2 = param2

class childclass(parentclass):
    def __init__(self,param1,param2,param3):
        super().__init__(param1,param2)
        self.param3 = param3

child_obj= childclass("value1","value2","value3")
print(child_obj.param1)
print(child_obj.param2)
print(child_obj.param3)

#13. Create a class called `Book` with a constructor that initializes the `title`, `author`, and `published_year` attributes. Provide a method to display book details.

class Book:
    def __init__(self,title,author,published_year):
        self.title = title
        self.author = author
        self. published_year=published_year

    def diplay_book_details(self):
         print(f"Title :{self.title}")
         print(f"Author : {self.author}")
         print(f"Published year :{self.published_year}")

book1 = Book("400 days ","Chetan Bhagat" ,2021)
print(book1.diplay_book_details())
print()
book2 = Book("THe Girl in the glass case","devashish parsana",2020)
print(book2.diplay_book_details())
#14. Discuss the differences between constructors and regular methods in Python classes.

"""Constructor --
- The primary purpose of a constructor is to initialize the attributes or properties of an object when it is created .
- The constructor is automatically  called when an object is creted .
-The constructor has a specific name ,__init__ and it is automatically recognized by python  as the method to be called when an object is created .

Regulat Method -
- It perform various actions or operations on objects .
-It is called  explicitly on an object . You need to reference the object and call the method .
-It can have any valid name on the object .
-It return the values based on their functionality.
 """
#15. Explain the role of the `self` parameter in instance variable initialization within a constructor.

""" When initializing instance variable within a constructors ,you use 'self' to asspciate those variables within the specific instance being created . This ensures that each instance of the class has its own set of variables,preventing conflicts between different instance."""
#16. How do you prevent a class from having multiple instances by using constructors in Python? Provide an example.

"""To prevent a class from having multiple instances,you can use a class variable to keep track of wheather an instance has already been created .By raising an exception if an attempt is made to create a second instance,you enforce the restriction ."""

class singletonclass:
    _instance_created= False

    def __init__(self):
        if singletonclass._instance_created:
            raise ValueError ("An instance of singleton class already exists .use getinstance() to get the instance.")
        else:
            singletonclass._instance_created = True

singleton_instance = singletonclass()

#second_instance =singletonclass()
#17. Create a Python class called `Student` with a constructor that takes a list of subjects as a parameter and initializes the `subjects` attribute.

class student:
    def __init__(self,subjects):
        self.subjects = subjects
    
subject_list = ["Math","Science","English"]
student_instance  = student(subject_list)

print(student_instance.subjects)
#18. What is the purpose of the `__del__` method in Python classes, and how does it relate to constructors?

""" The __del__ method is a special method that is called when an object is about to destroyed .
It is used for  cleanup and releasing resources associated with an object is about to de destroyed 

-The __del__ is used to delete an object  and it does not directly relate to constructors __init__ responsible for initializing the attribute of an object when it is created.
"""
#19. Explain the use of constructor chaining in Python. Provide a practical example.
""" Constructor chaining in python refers to the concept of calling one constructor from another within the same class.
This allows you to reuse cide and avoid redundancy when intializing objects with similar or related attributes."""

class Person:
    def __init__(self,name,age,):
        self.name = name
        self.age = age 

    def display_info(self):
        print(f"Name :{self.name},Age :{self.age}")

class student(Person):
    def __init__(self,name,age,student_id):
        super().__init__(name,age)
        self.student_id = student_id

    def display_student_info(self):
        self.display_info()
        print(f"student Id : {self.student_id}")

student1 =student("Agni",20,"S1234")
student1.display_student_info()
          

    

#20. Create a Python class called `Car` with a default constructor that initializes the `make` and `model` attributes. Provide a method to display car information

class car:
    def __init__(self,make ="Unknown",model ="Unknown"):
        self.make =make 
        self.model = model

    def display_car_info(self):
        return f"Make :{self.make} , Model : {self.model}"
    
car1 = car()
print(car1.display_car_info())

car2 =car("Toyota","camry")
print(car2.display_car_info())



##INHERITANCE ----->

#1. What is inheritance in Python? Explain its significance in object-oriented programming.
""" Inheritance - It allows a class to inherit attributes and methods from another class.
THe class that is inherit from is called parent class and the class that inherits is called the child or derived class .

Significance - 
- Inheritance allows a child class to reuse the code of its parent class .The child class automatically gains the acess to the attributes and method of the parent class.
-Child class can extend or override the behaviour of the parent class .This means you can add new functionality or modifying existing behaviour in a child class without modifying parent class .
-It is closely tied to polymorphism ,which allows objects of different classes to be treated as objects of a common base class.
"""

#2. Differentiate between single inheritance and multiple inheritance in Python. Provide examples for each.

""" Single inheritance -->
-In single inheritance a class can inherit from only one parent class .
THe class hierarchy form a linear structure .
It simplifies the design and is generally less complex ."""


"""
Multiple inheritance ---->
- In multiple inheritance a class can inherit from more than one parent class .
-The class hierarchy forms a more complex often diamond shaped structure .
It allows the child class to inherit attributes and methods from multiple sources .
"""
class parent:
       def p(self):
           pass
#single inheritance 
class child(parent):
       pass
#multiple inheritance 
    
class parent1:
    
    def pp(self):
        pass

class parent2:
     
     def pp2(self):
         pass
     
class child(parent1,parent2):
      pass




#3. Create a Python class called `Vehicle` with attributes `color` and `speed`. Then, create a child class called `Car` that inherits from `Vehicle` and adds a `brand` attribute. Provide an example of creating a `Car` object.

class vehicle:

    def __init__(self,color,speed):
        self.color = color 
        self.speed = speed


class Car(vehicle):

    def __init__(self,color,speed,brand):
        super().__init__(color,speed)
        self.brand = brand

car = Car( color ="red" ,speed = 120, brand ="Toyota")
print(f" Color : {car.color}")
print(f"Speed :{car.speed}")
print(f"Brand :{car.brand}")

#4. Explain the concept of method overriding in inheritance. Provide a practical example.

""" Method overriding is a concept in oops where a subclass provides a specific implementation for a method that is already defined in its  superclass.
The overridden method in the subclass has the same signature as the method in the superclass."""

class Animal:
    def make_sound(self):
        return "Generic animal sound "
    
class Dog(Animal):
    def make_sound(self):
        return "bark bark"
    
class Cat(Animal):
    def make_sound(self):
        return  "meow meow"
    
generic_animal =Animal()
dog = Dog()
cat = Cat()

print(generic_animal.make_sound())
print(dog.make_sound())
print(cat.make_sound())


#5. How can you access the methods and attributes of a parent class from a child class in Python? Give an example.

""" You can acess the methods and attributes of a parent class from a child class using the super () function. 
The super() function provides a way to refer to the parent class and invoke its method ."""

class parent:
    def __init__(self,name):
        self.name = name 

    def greet(self):
        return f"Hello,I am {self.name}"
    
class child(parent):
    def __init__(self,name,hobby):
        super().__init__(name)
        self.hobby = hobby

    def introduce(self):

        parent_greet = super().greet()
        return f'{parent_greet} and I love {self.hobby}'
    
child_obj = child(name ="AAru",hobby="making videos")

print(child_obj.greet())
print(child_obj.introduce())
print(child_obj.name)
print(child_obj.hobby)
#6. Discuss the use of the `super()` function in Python inheritance. When and why is it used? Provide an example.

""" Super() function is used in context of inheritance to refer to the parent class .
It provide a way to invoke method or acess attributes of the parent class

Uses -- 

- super() is often to call methods of the parent class from within the child class .
-This is useful when you want to extend or customize the behaviour  of a method in the child class"""

class parent:
    def __init__(self,value):
        self.value = value

    def perform_operation(self):

        result = str(self.value) + " some string"
        return result 

class child(parent):
    def __init__(self,value,additional_value):
        super().__init__(value)
        self.additional_value = additional_value
        
    def perform_operation(self):
        parent_result = super().perform_operation()
        combined_result = parent_result + f"- {self.additional_value}"
        return combined_result
    
child_instance = child(value =42,additional_value="extra")
print(child_instance.perform_operation())
#7. Create a Python class called `Animal` with a method `speak()`. Then, create child classes `Dog` and `Cat` that inherit from `Animal` and override the `speak()` method. Provide an example of using these classes.

class Animal:

    def speak(self):
        return "Animal Sound"


class Dog(Animal):
    def speak(self):
        return "Woof Woof!"
    
class Cat(Animal):
    def speak(self):
        return " Meow Meow"
    
animal = Animal()
print(animal.speak())

my_dog = Dog()
print(my_dog.speak())

my_cat = Cat()
print(my_cat.speak())
#8. Explain the role of the `isinstance()` function in Python and how it relates to inheritance.

"""isinstance function  -- 

-It is used to check if an object belongs to a specified class or a tuple of classes.
It returns True if the object is an instance of any of the specified classes  and False otherwise .

How it is related -- 
- It is often used to check the type of an object at runtime.
It can be useful when dealing with inheritance to verify wheather an object is an instance of a specific class 
-If an object is an instance of a subclass ,it is also considered an instance of the parent class.
It allows for dynamic and flexible coding ,as it doesn't rely on explicitly checking for a specific type but rather check the object's type at runtime."""
#9. What is the purpose of the `issubclass()` function in Python? Provide an example.

""" isubclass() function - 
-It is used to check if a class is a subclass of another class.
-It returns true ,if the class is a subclass of the second class,and False otherwise.

Purpose --

- To check whether one class is a subclass of another .
-It is useful in a scenario where you want to dynamically verify the relationship between classes.
-It is useful for dynamic handling of class hierarchies and writing code that adapts to various related clases.
-It allows dynamic typechecking aloowing you to write more flexible and adaptable code that works with different ckass hierarchies."""
#10. Discuss the concept of constructor inheritance in Python. How are constructors inherited in child classes?

"""Constructors are inherited in a child class just like any other method .
When a child class is created it automatically inherits the constructor (init) of its parent class.
"""
#11. Create a Python class called `Shape` with a method `area()` that calculates the area of a shape. Then, create child classes `Circle` and `Rectangle` that inherit from `Shape` and implement the `area()` method accordingly. Provide an example.

import math

class shape:
    def area(self):
        pass

class Circle(shape):
    def __init__(self,radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius**2
    
class Rectangle(shape):
    def __init__(self,width,height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height
    
circle1 = Circle(radius= 5)
rectangle1 = Rectangle(width= 5,height=3)

print("Circle Area : ",circle1.area())
print("Rectangle Area :",rectangle1.area())


#12. Explain the use of abstract base classes (ABCs) in Python and how they relate to inheritance. Provide an example using the `abc` module.

"""Abstract Base Classes - 
-It provide a way to define abstract classes and  abstract methods .
-It cannot be instantiated and typically contains one or more abstract method ,which must be implemented by its concrete subclasses .
"""

from abc import ABC ,abstractmethod

class shape(ABC):
    def area(self):
        """ Abstract method to calculate the area"""
        pass

class circle(shape):
    def __init__(self,radius):
        self.radius = radius 

    def area(self):

        return 3.14 *self.radius**2
    
class rectangle(shape):
    def __init__(self,width,height):
        self.width = width
        self.height = height 

    def area(self):
        return self.width*self.height
    
circle_instance = circle(radius=4)
rectangle_instance = rectangle(width=3,height=5)
print("Circle Area :",circle_instance.area())
print("Rectangle Area :",circle_instance.area())


#13. How can you prevent a child class from modifying certain attributes or methods inherited from a parent class in Python?

""" You can control acess to attributes and methods in a class using acess modifiers .
Python doesn't have true private or protected acess modifiers like some other language.Instead it relies on naming conventions to indicate the intended visivbility.

single underscore --- 
A single underscore before an attribute or method name suggests that it is intended for internal use and should be treated as protected.
THis is a convention and the attribute or method is still acessible .

Double underscore ---
A double underscore before an attribute or  method name invokes name mangling  .
It changes the name of the attribute in a way that makes it harder to accidentally override in a subclass."""


#14. Create a Python class called `Employee` with attributes `name` and `salary`. Then, create a child class `Manager` that inherits from `Employee` and adds an attribute `department`. Provide an example.

class Employee:
    def __init__(self,name,salary):
        self.name = name 
        self.salary = salary 

class Manager(Employee):
    def __init__(self,name,salary,department):
        super().__init__(name,salary)
        self.department= department

employee = Employee(name= "Riya",salary= 50000)
manager =Manager(name= "Aria",salary=70000,department="data scientiest")

print("Employee :",employee.name,employee.salary)
print("Manager :",manager.name,manager.salary,manager.department)

#15. Discuss the concept of method overloading in Python inheritance. How does it differ from method overriding?

""" Method Overloading --
-You can provide default values for function parameters ,allowing a single method to be called with different numbers of arguments .
This is a form of method overloading ,where a method can perform different actions based on the number or type of arguments provided .


Method Overriding - - 
-It occur in the context of inheritance when a subclass provides a specific impementation for a method that is already defined in its superclass.
-The overriding method in the subclass should have the same signature  as the method in the superclass."""
#16. Explain the purpose of the `__init__()` method in Python inheritance and how it is utilized in child classes.

""" The __init__method is a special method that serves as a constructor for a class .
It is called automatically when an object is created from the class .
The primary purpose of the __init__ method is to intialize the attributes of the object .

In the context of inheritance the __init__ method plays a crucial role in the child classes by allowing  them to initialize their own attributes in addition to the attribute inherited from the parent class .
"""
#17. Create a Python class called `Bird` with a method `fly()`. Then, create child classes `Eagle` and `Sparrow` that inherit from `Bird` and implement the `fly()` method differently. Provide an example of using these classes.

class Bird :
    def fly(self):
        print("Bird flying")

class Eagle(Bird):
    def fly(self):
        print("Eagle soaring high")

class Sparrow(Bird):
    def fly(self):
        print("sparrow fluttering around")


bird = Bird()
eagle =Eagle()
sparrow= Sparrow()

(bird.fly())
(eagle.fly())
(sparrow.fly())
#18. What is the "diamond problem" in multiple inheritance, and how does Python address it?

"""Diamond problem --
The diamond problem occur in programming language that support multiple inheritance when a partocular class is derived from two classes that have a common ancestor .
This create ambiguity in the inheritance hierarchy ,as there are multiple paths for the derived class to inherit the same method or attribute .

Solution -- 

It is adresses through  a mechanism called  C3 linearization .Python uses the C3 lineraization algorithm to establish a consistent order in which base classes are considered during method resolution .
This ensures that ambiguity is resolved and the method or attribute is inherited from a specific class in a predictable manner. """
#19. Discuss the concept of "is-a" and "has-a" relationships in inheritance, and provide examples of each.

""" Is a Relationship ---->

-This relationship is typically represented by inheritance . It implies that one class is a specialized version of another .
-Inheritance allows the derived class to inherit attribute and behaviour from the base class, promoting code reuse and establishing a hierarchial relationship.

Has a Relationship ---->
This relationship is tupically represented by composition .It implies that one class has another class as a component or member .
-  allows for building complex objects by combining simpler ones ,promoting flexibility and modularity."""

#is a Relationship- 

class vehicle:
    def __init__(self,brand):
        self.brand = brand

    def start_engine(self):
        print("Engine started ")

class car(vehicle):
    def drive(self):
        print("car is moving ")



my_car = car("Toyota")
my_car.start_engine()
my_car.drive

#Has a Relationship - 

class Engine:
    def start(self):
        print("Engine started")

class car:
    def __init__(self,brand):
        self.brand = brand
        self.engine = Engine()

    def drive(self):
        print("car is moving")

my_car = car("Toyota")
my_car.engine.start()
my_car.drive()



#20. Create a Python class hierarchy for a university system. Start with a base class `Person` and create child classes `Student` and `Professor`, each with their own attributes and methods. Provide an example of using these classes in a university context.

class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age

    
    def display_info(self):
        print(f"Name : {self.name} ,Age :{self.age}")


class student(Person):
    def __init__(self,name,age,student_id):
        super().__init__(name,age)
        self.student_id= student_id

    def study(self):
        print(f"{self.name} is studying")

class Professor(Person):
    def __init__(self,name,age,empoloyee_id):
        super().__init__(name,age)
        self.empoloyee_id = empoloyee_id

    def teach(self):
        print(f"{self.name} is teaching")
        


student1 = student("Aliya",20,"s1234")
professor1 = Professor("Dr.amit",45,"p45")

student1.display_info()
professor1.display_info()

student1.study()
professor1.teach()


##Encapsulation:
# 1. Explain the concept of encapsulation in Python. What is its role in object-oriented programming?

"""Encapsulation is one of fundamental concepts in oops and is often associated with the idea if bundling data and the method that operate on the data into a single unit known as a class.
It is achieved through the use of classes and acess modifiers.
It is basically hiding the details from user ."""
# 2. Describe the key principles of encapsulation, including access control and data hiding.

"""Encapsulation is a key principle in OOP that involve bundling the data and methods that operate on the data into a single unit known as a class.
The main objective of encapsulation are to provide a way to control acess to the internal details of a class and to hide the complexity of its implementation.

1.Acess control --->
-PUBLIC --  members of a class are public by default ,meaning they can be acessed from outside the class.
This is the least restrictive level of acess.

Protected acess - Members marked as protected are accesible within the class and its subclasses.
This level of acess is indicated by a single underscore prefix.

Private acess - Members marked as private are only accessible within the class itself.
This level of access is indicated by a double underscore prefix.

2.Data hiding - Encapsulation involves hiding the implementation details of a class from the outside world.
The internal state of the class should not be directly accessible or modifable from external code.

-Instead of direct acessing or modifying attributes ,encapsulation encourages the use of getter and setter methods.
These methods provide controlled acess to the internal state of the class,allowing validation or additional logic to be applied.

 """
# 3. How can you achieve encapsulation in Python classes? Provide an example.

""" Encapsulation in python classes can be achieved through a combinations of access modifiers and conventions.
Python provide acess modifiers in the form of single and double underscore to indicate the level of access control.
"""
#public Members - 

class Myclass:
    def __init__(self,data):
        self.data = data

    def process_data(self):
          pass

class Myclass:
    def __init__(self,data):
        self._data =data
    def  _process_data(self):
         pass
#private method-

class Myclass:
    def __init__(self,data):
        self.__data =data

    def __process_data(self):
          pass


# 4. Discuss the difference between public, private, and protected access modifiers in Python.

"""Public - 
-No underscore prefix 
-Members are acessible from anywhere ,both within the class and from outside the class.

Protected - 
- Single underscore prefix conventially indicates protected access.
-Members are acessible within the class and its subclass.
They can still be acesses from outside the class.
"""
# 5. Create a Python class called `Person` with a private attribute `__name`. Provide methods to get and set the name attribute.

class Person:
    def __init__(self,name):
        self.__name = name 

    def get_name(self):
        return self.__name
    def set_name(self, new_name):
        self.__name =new_name

person = Person("elvish Bhai")

current_name =person.get_name()
print(f"current name :{current_name}")

person.set_name("Elvish Bhai")

updated_name = person.get_name()
print(f"Updated name :{updated_name}")
# 6. Explain the purpose of getter and setter methods in encapsulation. Provide examples.

"""Getter and Setter method play a crucial role in encapsulation by providing controlled acess to the attribute of a class.
These methods allow external code to retrieve or modify the value  of private attributes, promoting  a secured and controlled interface with the class.

1.Control acess - Getter and setter method enable controlled access to the internal state of an object.
-They allow the class designer to define the conditions under which data can be retrierved or modified .

2.Validation and logic - Getter and setter  methods provide a convenient way to incorporate validations or additional logic when getting or setting values.
-This ensures that he internal state remains consistent and folloes specific rules.

3.Encapsulation - By encapsulating the internal representing of an object and providing access through methods ,the class can hide implement details from external code.

-Changes to the internal representation can be made without affecting external code.

"""

class Person:
    def __init__(self,name,age):
        self.__name = name
        self.__age =age

    def get_name(self):
        return self.__name
    
    def get_age(self):
        return self.__age
    
    #setter method with validation 
    def set_name(self,new_name):
        if isinstance(new_name,str):
            self.__name = new_name

        else:
            print("Invalid name format.")

    def set_age(self,new_age):
        if isinstance(new_age,int) and new_age >=0:
            self.__age = new_age
        else:
            print("Invalid age format")

person =Person("riya",12)

print(f"Name: {person.get_name()}")
print(f"Name:{person.get_age()}")

person.set_name("Reya")
person.set_age(17)

print(f"Updated Name :{person.get_name()}")
print(f"Updated age :{person.get_age()}")

# 7. What is name mangling in Python, and how does it affect encapsulation?

""" Name Mangling is a mechanism in python that alter the name ofa variable in a way that makes it more challenging to create conflicts with other variable in the same namespace.
This mechanism is primarly applied to attribute with a double underscore prefix in class definitions.The purpose of name mangling is to make these attribute more private by changing their names to include the class name as a prefix."""
# 8. Create a Python class called `BankAccount` with private attributes for the account balance (`__balance`) and account number (`__account_number`). Provide methods for depositing and withdrawing money.

class BankAccount:
    def __init__(self,account_number,initial_balance =0.0):
        self.__balance = initial_balance
        self.__account_number = account_number
    def get_account_number(self):
        return self.__account_number
    
    def get_balance(self):
        return self.__balance
    
    def deposit(self,amount):
        if amount>0:
            self.__balance+=amount
            print(f"Deposit {amount}.New balance :{self.__balance}")

        else:
            print("Invalid deposit amount .please deposit a positive amount ")

    def withdraw(self,amount):
        if amount>0 and amount <=self.__balance:
            self.__balance -= amount
            print(f"Withdraw {amount} .New balance :{self.__balance}")
        elif amount <=0:
            print("Invalid withdraw amount.")
        else:
            print("Insufficient funds .")

account = BankAccount(account_number="123242344",initial_balance=1000)
print(f"Account number :{account.get_account_number()}")
print(f"Inital Balance :{account.get_balance}")

account.deposit(500)
account.withdraw(200)

print(f"Final balance :{account.get_balance()}")
# 9. Discuss the advantages of encapsulation in terms of code maintainability and security.

""" Advantages in terms of Maintenence ---
1.Modularity - '
-Encapsulation allows you to design classes in a modular fashion,where each class represents a self-containes unit with its own set of behaviours and attributes.
-Changes to one class don't necessarily  affect other parts of the program,making it easily to understand,modify,and extended.

2.Abstraction- 
-Encapsulation hides the internal details of an object and exposes only what is necessary for external use.
This abstraction simplifies the complexity of the code and allows developers to focus on high level functionality without worrying about the implementation details.

3.Ease of Modification - 
-Since the internal implementation of an object is hidden,modifications can be made to the interanal structure of a class without affecting the code that uses the class.

4.Code Organization - 
-Encapsulation promotes a clean and organized code structure.
By encapsulating related data and behaviour within  a class, the code becomes more readable and easier to manage.

Advantages in terms of security
1.Acess control -
- Encapsulation helps control access to the internal state of an object by using access modifiers.

2.Data Hiding 
- It hides the internal detail of an object's implementation .This not only protects the internal state of the object but also prevents external code from depending on implementaion details.

3.Encapsulation of Invariants 
-Invariants are condition that must always be true during the execution of an program.
Encapsulation allows the encapsulation of these invariants within a class,ensuring that they are maintained and preventing external code from violating them.

4.Enhanced Security Through Methodology 
-Encapsulation encourages the use of getter and setter method to interact with the internal state of an object .This allows for validation and control over the data  being manipulated , adding an extra layer of security by preventing invalid or malicious data from entering the system.
"""
# 10. How can you access private attributes in Python? Provide an example demonstrating the use of name mangling.

class Myclass:
    def __init__(self):
        self.__private_attribute = 32

    def get_private_attribute(self):
        return self.__private_attribute
    
obj =Myclass()

value = obj.get_private_attribute()
print("value of private attribute:",value)
# 12. Explain the concept of property decorators in Python and how they relate to encapsulation.

"""Property decorator are a way to implement getter,setter,and deleter methods for class attributes.They allow you to define  methods that can be acessed like attributes ,providing a clean interface with object properties.

Relation to Encapsulation -
1.@property 
-Decorates a method to make it a read-only property.
This method is called when the property is acessed.

2.@<property_name>.setter
- Decorates a method to make it a setter for the property .This method is called when the property is assigned a new value.

3.@<property_name>.deleter
-Decorates a method to make it a delete for the property .This method is called when the property is deleted using the del statement.
"""
# 13. What is data hiding, and why is it important in encapsulation? Provide examples.

"""Data hiding is a fundamental concept in  object-oriented programming that refers to the practice of restricting the direct acess to some of an object components and preventing the external world from knowing the internal details of an object .
"""

class BankAccount:
    def __init__(self,balance):
        self.balance = balance

    def deposit(self,amount):

        if amount >0:
            self.balance += amount
        else:
            print("Invalid deposit amount")

    def withdraw(self,amount):
        if amount>0 and amount <=self._balance:
            self._balance -= amount
        else:
            print("Invalid withdraw amount")

    def get_balance(self):
        return self.get_balance
    
# 11. Create a Python class hierarchy for a school system, including classes for students, teachers, and courses, and implement encapsulation principles to protect sensitive information.
    
class person:
    def __init__(self,name,age):
        self._name = name
        self._age = age

    def get_name(self):
        return self._name
    
    def get_age(self):
        return self._age
    
class student(person):
    def __init__(self,name,age,student_id):
        super().__init__(name,age)
        self._student_id = student_id
        self._courses =[]

    def enroll_course(self,course):
        self._courses.append(course)
        print(f"{self.get_name()} has enrolled in {course.get_course_name()}")

    def  view_courses(self):
        print(f"{self.get_name()}'s enrolled courses :{','.join(course.get_course_name() for  course in self._courses)}")


class Teacher(Person):
    def __init__(self,name,age,employee_id):
        super().__init__(name,age)
        self._employee_id = employee_id
        self._course_taught =[]

    def assign_course(self,course):

        self._course_taught.append(course)
        print(f"{self.get_name()} is now teaching {course.get_course_name()}")

    def view_taught_courses(self):
        print(f"{self.get_name()}'s taught course :{' ,'.join(course.get_course_name() for course in self._course_taught)}")


class course:
    def __init__(self,course_name,course_code):
        self._course_name = course_name
        self._course_code = course_code

    def get_course_name(self):
        return self._course_name
    
    def get_course_name(self):
        return self._course_name
    
    def get_course_code(self):
        return self._course_code
    

student1 = student(name ="Riya",age=18,student_id = "s1234")
teacher1 =Teacher(name="jaishankar",age= 35,employee_id="e345")
course1 = course(course_name="mathematics",course_code="Mat123")

student1.enroll_course(course1)

teacher1.assign_course(course1)

student1.view_courses()
teacher1.view_taught_courses()
# 14. Create a Python class called `Employee` with private attributes for salary (`__salary`) and employee ID (`__employee_id`). Provide a method to calculate yearly bonuses.

class Employee:
    def __init__(self,salary,employee_id):
        self.__salary = salary
        self.__employee_id = employee_id

    def get_salary(self):
        return self.__salary
    
    def get_employee_id(self):
        return self.__employee_id
    
    def calculate_bonus(self,bonus_percetage):
        if bonus_percetage <0 or bonus_percetage>1:
            raise ValueError("Bonus percentage should be between 0 and 1")
        
        yearly_bonus = self.__salary *bonus_percetage
        return yearly_bonus
    
employee1 =Employee(salary =50000,employee_id="E0012")

print("Employee Id ;",employee1.get_employee_id())
print("Salary:",employee1.get_salary())


bonus_percetage = 0.1
yearly_bonus= employee1.calculate_bonus(bonus_percetage)
print(f"Yearly Bonus: Rs.{yearly_bonus}")
# 15. Discuss the use of accessors and mutators in encapsulation. How do they help maintain control over attribute access?

""" Accessors and mutators commonly known as getter and setter, are methods used in object oriented programming to control access to the attrubute of a class.
They play a crucial role in implementating incapsulation by providing a way to interact with and manipulate the internal state of an object while maintaining control over attribute acess.


Benefits -->
1.control acess -
-Accessors and mutators allow developers to define how internal attribute are accessed and modified .
This ensures that access to sensitive data is controlled promoting encapsulation

2.Validation and Logic 
-By using mutators,developers can incorporate validations logic before allowing changes to private attributes .This helps maintain the integrity of the object's state and prevents invalid or  unitended modifications.

3.Abstraction 
-Accessors and mutators provide a level of abstraction by hiding the internal detail of attribute access.

4.Flexibility 
- Since acess to attributes is mediated through methods,changes to the internal representations of attributes can be made without affecting the external code that uses the class.
"""
# 16. What are the potential drawbacks or disadvantages of using encapsulation in Python?

""""Drawbacks -

1.Increase code complexity 
-Encapsulation often involves creating more methods and structures to control acess to attributes.
This can lead to increase code complexity .

2.Potential Overhead 

The use of getter and setter may introduce a slight performance overhead compared to direct attribute acess.
While this overhead is usually negligible ,in performance critical scenarios ,it might be considered.

3.Reduced Readibility for Simple Cases 
- In some cases , using encapsulation for very simple classes with straightforward attributes might result in code that is less concise and less readable .Acessing attributes directly might be more natural in such scenarios.

4.Boilreplate code 
-The need to create getter and setter methods for each attribute can lead to boilerplate code,especially in languages where propety syntax is not availaible.
This can make the code verbose and less  maintainable.

5.Difficulty in Debugging 
- Debugging encapsulated code might be more challenging , especially when dealing with complex inheritance hierarhies or when trying to understand the internal state of an object that has limited Visibility.

7.Potential Misuse of Accessors and Mutators
- if not properly design , accessors and mutators might be misused ,leading to unexpected behavior.
"""
# 17. Create a Python class for a library system that encapsulates book information, including titles, authors, and availability status.

class library_system:
    def __init__(self,title,author):
        self.__title = title
        self.__author = author
        self.__availability_status = True

    def get_title(self):
        return self.__title
    
    def get_author(self):
        return self.__author
    
    def get__availabilty(self):
        return self.__availability_status
    
    def check_out(self):
        if self.__availability_status:
            print(f"Book '{self.__title}' by {self.__author} checked out")
            self.__availability_status = False

        else:
            print(f"Sorry ,{self.__title} by {self.__author } is currently checked out")

    def return_books(self):
        if not self.__availability_status:
            print(f"Book{self.__title} by {self.__author} returned")
            self.__availability_status = True
        else:
            print(f"Error {self.__title} is not checked out")



book1 =library_system(title="Girl in the glass case",author="Devashish parsana")
book2 =library_system(title ="400 Days",author= "Chetan Bhagat")

print("Book1 title :",book1.get_title())
print("Book 1 Author:",book1.get_author())
print("Book1 Availaibility :","Availaible" if book1.get__availabilty() else "checked out")

book1.check_out()
book2.check_out()
book1.return_books()

print("Book1 availaibility :", "Availaible" if book1.get__availabilty() else "checked out")
print("Book 2 Availaibilt:" ,"Availaible"  if book2.get__availabilty() else "checked out")
# 18. Explain how encapsulation enhances code reusability and modularity in Python programs.

""" Code Reusaility
1.Encapsulation as a Black Box:

Encapsulation allows you to treat an object as a "black box" where the internal details are hidden. Users of the class don't need to know how the object is implemented internally; they only need to interact with its public interface.
2.Reuse Without Understanding Implementation:

-Encapsulation enables the reuse of code without understanding its internal workings. If a class provides a well-defined interface (public methods), it can be reused in different parts of the program or even in different projects without users having to know the details of its implementation.
3.Library and Module Development:

Encapsulation encourages the development of libraries and modules. A well-designed class can be packaged as a module or a library, making it easy for other developers to import and use it in their projects. This promotes the reuse of code across different applications.
4.Inheritance and Polymorphism:

Encapsulation works hand in hand with inheritance and polymorphism. Subclasses can inherit the attributes and methods of a base class, promoting code reuse. Polymorphism allows objects of different classes to be treated as instances of a common base class, facilitating interchangeable use.


Modularity:
1.Clear Separation of Concerns:

Encapsulation promotes a clear separation of concerns by organizing code into modular units (classes). Each class encapsulates a specific set of functionalities related to a particular concept or entity, making the code more modular and easier to manage.
2.Ease of Maintenance:

Modules encapsulate related functionality, making it easier to locate and modify code. When a change is required, developers can focus on the specific module or class without affecting the rest of the program. This enhances code maintainability.
3.Reduced Complexity:

By encapsulating details within classes, the overall complexity of the program is reduced. Modules with well-defined interfaces and limited interactions provide a higher level of abstraction, making the code more understandable and easier to reason about.
4.Isolation of Changes:
Changes to the internal implementation of a class do not affect the code that uses the class, as long as the public interface remains consistent. This isolation of changes ensures that modifications can be made within a module without causing ripple effects throughout the entire codebase."""
# 19. Describe the concept of information hiding in encapsulation. Why is it essential in software development?
"""
KEY ASPECT OF INFORMATION HIDING-
1.Private Implementation Details:
Information hiding ensures that the internal implementation details of an object, such as its data members or methods, are kept private. This means that the internal workings are not exposed to external code.

2.Public Interface:
Only a specific set of methods, known as the public interface, is made accessible to external code. This interface defines how external entities can interact with the object. The public interface is designed to be stable and resistant to changes in the internal implementation.
3.Abstraction:
Information hiding promotes abstraction by allowing users to interact with objects at a higher level without being concerned about the low-level details. Abstraction simplifies the complexity of a system, making it easier to understand and use.

4.Reduced Complexity and Coupling:
By hiding unnecessary details, information hiding reduces the complexity of an object and minimizes the dependencies between different parts of a program. This results in lower coupling, meaning that changes in one part of the system are less likely to impact other parts.


Why Information Hiding is Essential in Software Development:
1.Security and Privacy:
Information hiding enhances security by protecting sensitive data and preventing unauthorized access. Private details, such as passwords or internal algorithms, are shielded from external entities.

2.Maintainability:
Encapsulation with information hiding improves maintainability. Changes to the internal implementation can be made without affecting the external code as long as the public interface remains unchanged. This isolation of changes simplifies maintenance efforts.

3.Flexibility and Evolution:
Information hiding allows for more flexible and evolvable software. The internal details of an object can evolve over time without impacting external code. This supports the long-term sustainability of software systems.

4.Encapsulation and Modularity:
Information hiding is a fundamental aspect of encapsulation, contributing to modularity. Encapsulated modules can be treated as independent units, allowing developers to focus on specific components without being burdened by unnecessary details.

5.Team Collaboration:
In a collaborative development environment, information hiding facilitates teamwork. Developers can work on different modules concurrently, and as long as the public interfaces are adhered to, integration issues are minimized.

6.Reduction of Complexity:
By providing a simplified view of an object's functionality through its public interface, information hiding reduces the cognitive load on developers. It allows them to focus on what an object does rather than how it achieves it."""
# 20. Create a Python class called `Customer` with private attributes for customer details like name, address, and contact information. Implement encapsulation to ensure data integrity and security

class Customer:
    def __init__(self,name,adress,contact_info):
        self.__name =name
        self.__adress = adress
        self.__contact_info = contact_info

    def get_name(self):
        return self.__name
    
    def get__address(self):
        return self.__adress
    
    def get__contact_info(self):
        return self.__contact_info
    
    def update_address(self,new_address):
        self.__adress = new_address

    def updated_contact_info(self,new_contact_info):
        self.__contact_info = new_contact_info


customer1 = Customer(name="ari",adress="Lajpat nagar",contact_info="ari@email.com")


print("Customer Name :",customer1.get_name())
print("Customer Adress:",customer1.get__address())
print("Customer contact :",customer1.get__contact_info())

customer1.update_address("sidhart nagar")
customer1.updated_contact_info("ari112@mail.com")

print("Updated customer adress:",customer1.get__address())
print("updated customer contact :",customer1.get__contact_info())


##Polymorphism:
#1. What is polymorphism in Python? Explain how it is related to object-oriented programming.

""" Polymorphism in python is a concept in object oriented programming that allows objects of different types to be treated as objects of common type.It enables a single interface to represent different types of objects

HOW IT IS RELATED TO OOP--->

1.Code Reusability - 
polymorphism allows you to write generic code that can operate on object of various types .
This promotes code reusability as the same code can be used with different classes,provide they adhere to a common interface.


2.Flexibility and Extensibility - 
By designing programs with polymorphism .you create systems that are  more flexible and extensible .New classes can be modify existing code,as long as they conform to the estiblished interace.


3.Readability and Maintenance -
Polymorphism code tends to be more readable and easier to maintain .Instead of dealing with specific implementation for each class,developers can work with a common interface,making the code more intutitive and less error prone.

4.DynamicbBinding-
Runtime polymorphism ,achieve through method overriding allows for dynamic binding .The dicision of which method to execute is made at runtime based on the actual type of the object ,enabling more flexibility in the program 's behaviour  """
#2. Describe the difference between compile-time polymorphism and runtime polymorphism in Python.

""""Compile time polymorphism 
1.Method Overloading - 
Method overloading allows the definition of multiple methods with the same name in a class, but with different parameters.

-The appropriate method is selected during compile time based on the number and type of arguments passed.

2.Operator overloading - 
Operator overloading  allows you to define how operators behave for objects of your own classes.
The appropriate method is called during compile time based on the operator and the types of operands.

RUNTIE POLYMORPHISM -
1.Method Overriding -
It occurs when a subclass provides a specific implementation for a method that is already defined in its superclass.
THe decision on which method to call is made during runtime based in the actual type on the object.
"""
#3. Create a Python class hierarchy for shapes (e.g., circle, square, triangle) and demonstrate polymorphism through a common method, such as `calculate_area()`.

import math 

class shape:
    def calculate_area(self):
        pass 

class circle(shape):
    def __init__(self,radius):
        self.radius = radius

    def calculate_area(self):
        return math.pi * self.radius**2
    
class square(shape):
    def __init__(self,side):
        self.side = side
    
    def calculate_area(self):
        return self.side**2
    
class Triangle(shape):
    def __init__(self,base,height):
        self.base = base 
        self.height = height

    def calculate_area(self):
        return  0.5* self.base *self.height
    
shapes = [circle(5),square(4),Triangle(3,5)]

for shape in shapes:
    area = shape.calculate_area()
    print(f"Area of {type(shape).__name__}: {area:.2f}")
#4. Explain the concept of method overriding in polymorphism. Provide an example.

"""Method overriding is a concept in oop that allows a subclass to provide a specific implementation for a method that is already defined in its superclass
The overridden method in the subclass has the same signature as the method in the superclass.
When an object  of the subclass is used,the overridden method in the subclass is called instead of the method in the superclass."""

#example -

class Animal:
    def make_sound(self):
        return "generic animal sound"
    
class Dog(Animal):
    def make_sound(self):
        return "Woof"
    
class Cat(Animal):
    def make_sound(self):
        return "Meow!"
    
generic_animal = Animal()
dog = Dog()
cat = Cat()

print(generic_animal.make_sound())
print(dog.make_sound())
print(cat.make_sound())

#5. How is polymorphism different from method overloading in Python? Provide examples for both.

"""Polymorphism -
It allows objects of different types to be treated as objects of a common type.
It enables a single interfaces to represent different types of objects.


Method overloading - 
It involves defining multiple methods with the same name ina class, but with differnt parameters .

Differences - 
1.polymorphism - Focuses on providing a common interface for different types of objects.
Method overloading - Focuses on providing multiple methods with the same name but different parameters within the same class.

2.Execution Time -
Polymorphism - Decision on which method to call is made at runtime.
Method Overloading - Decision on which method to call is made at compile time based on the number and types of arguments .

3.Number of  method - 
Polmorphism - Typically involves a single method name that is overridden in subclass.
Method Overloading - Involoves multiple methods with the same name but different parameters with the same class."""
#6. Create a Python class called `Animal` with a method `speak()`. Then, create child classes like `Dog`, `Cat`, and `Bird`, each with their own `speak()` method. Demonstrate polymorphism by calling the `speak()` method on objects of different subclasses.
class Animal:
    def speak(self):
        return f"Animal Sound"
    
class Dog(Animal):
    def speak(self):
        return "woof woof"
    
class Cat(Animal):
    def speak(self):
        return "Meow Meow!"
    
class Bird(Animal):
    def speak(self):
        return "Chirp Chirp"
    
def animal_sounds(animal):
    return animal.speak()

dog = Dog()
cat = Cat()
bird =Bird()

print(animal_sounds(dog))
print(animal_sounds(cat))
print(animal_sounds(bird))

#7. Discuss the use of abstract methods and classes in achieving polymorphism in Python. Provide an example using the `abc` module.

""" Abstract  methods and classes in python ,often used in conjunction with the abc module, provide a way to enforce a common interface methods that must be implemented  by their subclasss.
This approach ensures that all subclasses adhere to a specific contract,
facilitating polymorphism by allowing objects of different types to be treated uniformly."""'''

#example - 

from abc import ABC,abstractmethod
import math
class Shape(ABC):
    @abstractmethod
    def calculate_area(self):
        pass

class Circle(Shape):
    def __init__(self,radius):
        self.radius = radius 

    def calculate_area(self):
        return math.pi * self.radius **2
    
class square(Shape):
    def __init__(self,length):
        self.length = length 

    def calculate_area(self):
        return self.length **2
    
shapes = [Circle(4),square(8)]

for shape in shapes:
    area = shape.calculate_area()
    print(f"Area of{type(shape).__name__} :{area:.2f}")
#8. Create a Python class hierarchy for a vehicle system (e.g., car, bicycle, boat) and implement a polymorphic `start()` method that prints a message specific to each vehicle type.
class Vehicle:
    def __init__(self,brand,model):
        self.brand = brand
        self.model = model

    def start(self):
        print(f"Starting{self.brand} {self.model}")
class Car(Vehicle):

    def __init__(self,brand,model,num_doors):
        super().__init__(brand,model)
        self.num_doors = num_doors

    def start(self):
        print(f"starting the {self.num_doors} - door car :{self.brand}{self.model}")

class Bicycle(Vehicle):
    def __init__(self, brand, model,num_gears):
        super().__init__(brand,model)
        self.num_gears = num_gears

    def start(self):
        print(f"padaling the {self.brand} {self.model} bicycle with {self.num_gears} gears.")

class Boat(Vehicle):
    def __init__(self,brand,model,num_engines):
        super().__init__(brand,model)
        self.num_engines = num_engines

    def start(self):
        print(f"Starting the boat :{self.brand} {self.model} with {self.num_engines} engines.")

car = Car("Toyota","camry",4)
bicycle = Bicycle ("Schwin","mountain Bike",21)
boat = Boat("Sea Ray","sudancer",2)

car.start()
bicycle.start()
boat.start()

#9. Explain the significance of the `isinstance()` and `issubclass()` functions in Python polymorphism.

"""isinstance() and issubclass() are built in functions that play a significant role in working with polymorphism .
They help determine the relationships between objects and classes ,facilating more flexible and dynamic programming .

1.isinstance() function -
-checks if an instance of a particular class or a tuple of classes.
-Returns True if the object is an instance of the specified class or a tuple if classes,otherwise it returns false.
-It is useful in polymorphism when you want to check if an object belongs to a specific class or any of its subclasses.
This is handy when dealing with collection of objects of different types.


2.issubclass() function 
- checks if a class is a subclass or another class or a tuple of class.
-Returns True if the class is a subclass of the specified class or a tuple of classes,otherwise,it returns False.
-It helps in polymorphism when you want to check the inheritance relationship between classes.
It allow you to ensures that a particular class is a subclass of another before making assumption or decisions based on that relationship.

"""
#10. What is the role of the `@abstractmethod` decorator in achieving polymorphism in Python? Provide an example.

""" The @abstractmethod decorator is part of the abc (Abstract base class ) module in python .
It is used to declare abstract methods in abstract classes .Abstract methods are methods that are declared in a base class but don't habe an implementation in that class.
"""
#example - 

class Storage(ABC):
    @abstractmethod
    def store_data(self,data):
        pass

class Localdisk(Storage):
    def store_data(self,data):
        print(f"storing data locally :{data}")

class Cloudstorage(Storage):
    def store_data(self, data):
         print(f"Uploading data to the cloud : {data}")

data_to_store = "sample data "

local_storage = Localdisk()
cloud_storage = Cloudstorage()



storage_davices =[local_storage,cloud_storage]

for storage_davice in storage_davices:
    storage_davice.store_data(data_to_store)


#11. Create a Python class called `Shape` with a polymorphic method `area()` that calculates the area of different shapes (e.g., circle, rectangle, triangle).

class Shape:
    def area(self):
        pass

class Circle:
    def __init__(self,radius):
        self.radius = radius 

    def area(self):
        return math.pi * self.radius**2
    
class Rectangle:
    def __init__(self,length,bredth):
        self.length =length 
        self.bredth = bredth 

    def area(self):
        return self.length *self.bredth
    
class Triangle:
    def __init__(self,base,height):
        self.base = base 
        self.height = height

    def area(self):
        return 0.5*self.base *self.height

circle = Circle(5)
rectangle =Rectangle(3,5)
triangle = Triangle(2,7)

shapes =[circle,rectangle,triangle]

for shape in shapes:
    print(f"Area of the shape :{shape.area():.2f}")
#12. Discuss the benefits of polymorphism in terms of code reusability and flexibility in Python programs.

"""Code Reusability - 

1.Reusable interface - Polymorphism allows you to define a common interface that can be shared among multiple classes.
This promotes code reuse because different classes can implement the same interface ,making it easy to interchange objects without modyfying the client code.

2.Common Functionality - By using polymorphism ,you can create a set of classes that share a common bade class or interface and prvide their own specialized implementations.
This makes it possible to reuse the common functionality defined in the base class across different subclass.

2.Flexibility - 

1.adaptability - polymorphism allows your cide to be more adaptable to changes.
New classes can be added without modyfying existing code as long as they adhere to the common interface .This is especially valuable in large projects of frameworks where components may evolve independently .

2.plug and play components - since polymorphism relies on a shared interface ,it enables the development of plug and play component .New classes can be seamlessly integrated into introducing errors in the existing code .

3.Simplified code maintenence -
1.Reduced Coupling - Polymorphism helps reduce tight coupling between different parts of your code.
The code that uses polymorphic interface is not concerned with the specific implementation details of the objects.

2.Ease updates - when you need to make updates or changes to a specific functionality,you can do so in one place without affecting the code that uses it .
This simplifies maintenance and reduces the likelihood of introducing bugs."""
#13. Explain the use of the `super()` function in Python polymorphism. How does it help call methods of parent classes?

"""super() function in python id used to call  methods of a parent class from within a subclass.It provides a way to invoke method in the superclass,allowing for cooperative multiple inheritance and ensuring that the methods  of the parent class are executed before those of the subclass.
The primary use of super() is in the context of method overriding .When a subclass overrides a method from its parent class, it may still want to leverage the behaviour of the overridden method in the parent class.
This is where super() become valuable."""
#14. Create a Python class hierarchy for a banking system with various account types (e.g., savings, checking, credit card) and demonstrate polymorphism by implementing a common `withdraw()` method.

class BankAccount:
    def __init__(self,account_number,balance):
        self.account_number = account_number
        self.balance = balance 

    def withdraw(self,amount):
        if amount <=0:
            print("Invalid withdraw amount")
        elif amount>self.balance:
            print("Insufficient funds.")
        else:
            self.balance-= amount
            print(f"Withdrawl of rs.{amount} successful.Remaining balance : rs.{self.balance}")


class Savingaccount(BankAccount):
    def __init__(self,account_number,balance,interest_rate):
        super().__init__(account_number,balance)
        self.interest_rate = interest_rate

    def withdraw(self,amount):
         penalty =5
         super().withdraw(amount+penalty)
         print(f"Penalty of {penalty} applied for withdrawing from saving account.")

class checkingAccount(BankAccount):
    def __init__(self,account_number,balance,overdraft_limit):
        super().__init__(account_number,balance)
        self.overdraft_limit = overdraft_limit

    def withdraw(self,amount):
        if amount > self.balance + self.overdraft_limit:
            print("Withdrawal not allowed. Exceeds overdraft limit.")

        else:
            super().withdraw(amount)


class Creditcardaccount(BankAccount):
    def __init__(self,account_number,balance,credit_limit):
        super().__init__(account_number,balance)
        self.credit_limit= credit_limit

    def withdraw(self, amount):
        if amount > self.balance +self.credit_limit:
            print("Withdrawl not allowed .")
        else:
            super().withdraw(amount)

savings_account = Savingaccount(account_number="sa1233" ,balance=1000,interest_rate=0.02)
checking_account = checkingAccount(account_number="CA456", balance=2000, overdraft_limit=500)
credit_card_account =Creditcardaccount(account_number="CC789", balance=-500, credit_limit=1000)

accounts = [savings_account, checking_account, credit_card_account]

for account in accounts:
    print(f"\nAccount Type: {type(account).__name__}")
    account.withdraw(200)

#15. Describe the concept of operator overloading in Python and how it relates to polymorphism. Provide examples using operators like `+` and `*`.

""" Operator overloading in python refers to the ability to define or redefine the behaviour of standard operators for user- defined objects or classes. It allows you to give special meaning to operators based on the context in which they are used .This features enables a class to define its own behaviour for standard operators ,making it more expressive and intutive .
It allows objects of different classes to respond to the same operator in a way that is appropriate for the specific class. 
This is achieved by defining special methods in a class that corresponds to the + operator and the __mul__ method corresponds to the * operator ."""

class Point:
    def __init__(self,x,y):
      self.x = x
      self.y =y 

    def __add__(self,other):
        if isinstance(other,Point):
            return Point(self.x + other.x,self.y + other.y)
        else:
            raise ValueError("Unsupported operand type for +")
        
    def __mul__(self,scalar):

        if isinstance(scalar,(int,float)):
            return Point(self.x *scalar, self.y* scalar)
        else:
            raise ValueError("Unsupported operand type for *")
        
    def __str__(self):
        return f"{self.x},{self.y}"
    

point1 = Point(1,2)
point2 =Point(3,4)

result_adittion = point1 + point2 
print("Addition Result :",result_adittion)

result_multiplication =  point1*2
print("Multiplication Result :",result_multiplication)
#16. What is dynamic polymorphism, and how is it achieved in Python?

""" Dyamic polymorphism also known as runtime polymorphism ,is a concept in oop where the actual method or operation to be performed is determine at runtime.It allows different classes to be treated uniformly through a common interface ,and the specific methods to be executed is resolved during program execution based on the actual type of the object.
1.Inheritance 
- Subclass can provide a specific implementation for a method that is already defined in thier superclass.

2.AbstractBasedClasses 
-Python provides the abc module which allows you to create abstract classes with abstract method .

3.DuckTyping 
-Python follows the principle of ducktyping which means that the type or class of an object is determined by its behaviour rather than its explicit type.
"""
#17. Create a Python class hierarchy for employees in a company (e.g., manager, developer, designer) and implement polymorphism through a common `calculate_salary()` method.

class Employee:
    def __init__(self,name,role):
        self.name = name 
        self.role = role 

    def calculate_salary(self):
        pass 

class Manager(Employee):
    def __init__(self,name,salary,bonus):
        super().__init__(name,role ="Manager")
        self.salary = salary 
        self.bonus = bonus 

    def calculate_salary(self):
        return self.salary + self.bonus
    
class Developer(Employee):
    def __init__(self,name,salary,language):
        super().__init__(name,role = "Developer")
        self.salary = salary 
        self.language = language


    def calculate_salary(self):
        return self.salary
    
class Designer(Employee):
    def __init__(self,name,salary,tools_used):
        super().__init__(name, role = "Designer")
        self.salary = salary
        self.tools_used = tools_used

    def calculate_salary(self):
        return self.salary
    

manager = Manager(name="john",salary=80000,bonus=15000)
developer = Developer(name= "alia",salary = 70000, language = "python")
designer = Designer(name = "bob",salary = 75000,tools_used="sketch")

employee = [manager,developer,designer]

for employe in employee:
    print(f"{employe.name} - {employe.role} : salary rs.{employe.calculate_salary()}")
#18. Discuss the concept of function pointers and how they can be used to achieve polymorphism in Python.

"""FUNCTION POINTERS IN PYTHON - 
1.First class functions 
-IN python functions are first class citizen ,which means they can be assigned to vaiable.

2.HigherOrder functions 
-Higher order functions take function as arguments or return functions as results.
This enables the use of function pointers in various scenarios .

Achieving polymorphism with function Pointers :
using function pointers,you can achieve polymorphism python by defining a common interface and allowing different implementation to be used interchangeabl .This is similar to how polymorphism works with classes and method overriding .
"""
#19. Explain the role of interfaces and abstract classes in polymorphism, drawing comparisons between them.

"""
Abstract classes - 
- Abstract classes are classes that cannot be instantiated on their own .They typically serves as a blueprint for other classes.
-Abstract classes may contain both abstract and concrete methods.
-Abstract classes can also have instance variables,constructors and non  abstract methods.

2.Inheritance 
-Abstract classes support the concept of inheritance .Other classes  can extend an abstract class.
-Subclasses must provide concrete implementation for all abstract methods defined in the abstract class.

3.polymorphism 
-Abstract classs enables polymorphism by allowing objects of different subclasses to  be treated as object of the abstract class type .


INTERFACES 

1.Definition - 
-Interfaces are collection of abstract method without any implementation .
-They represent a contract that classes must adhere to by implementing all the methods defined in the interface.

2.Inheritance - 
-Interfaces support multiple inheritance,meaning a class can implement multiple interfaces.
-A class that implements an interface must provide concrete implementation for all methods declared in the interface.

3.polymorphism 
- Interface play a crucial role in achieving polymorphism by allowing objects of different classes to be treated as objects of the interface type.


Comparisons - 

1.Multiple inheritance 
-Abstract classes support single inheritance, meaning a class can only inherit from one abstract class.
-Interfaces support multiple inheritance  as a class can implement multiple interfaces.

2.Implementations 
-Abstract classes can have both abstract and concrete methods providing a mix of flexibility and structure.
-Interfaces only contains abstract methods,promoting a  more abstract and contract based design .

3.construction 
-Abstract classes can have constructors allowing them to initialize instance variable.
-Interfaces cannot have constructors or instance variables.

"""
#20. Create a Python class for a zoo simulation, demonstrating polymorphism with different animal types (e.g., mammals, birds, reptiles) and their behavior (e.g., eating, sleeping, making sounds).

class Animal:
    def __init__(self,name):
        self.name = name 

    def make_sound(self):
        pass
    def eat(self):
        pass
    def sleep(self):
        pass

class Mammal(Animal):
    def __init__(self,name):
        super().__init__(name)

    def make_sound(self):
        return "Mammal sound"
    def eat(self):
        return "Mammal is eating "
    def sleep(self):
        return "Mammal is sleeping"
class Bird(Animal):
    def __init__(self,name):
        super().__init__(name)

    def make_sound(self):
        return "Bird sound"
    
    def eat(self):
        return "Bird is eating"
    
    def sleep(self):
        return "Bird is sleeping"
    
class Reptile(Animal):
    def __init__(self,name):
        super().__init__(name)

    def make_sound(self):
        return "Reptile sound"
    
    def eat(self):
        return "Reptile is eating"
    def sleep(self):
        return "Reptile is sleeping"
    
class Zoo:
    def __init__(self):
        self.animals=[]

    def add_animal(self,animal):
        self.animals.append(animal)

    def simulate_zoo(self):
        for animal in self.animals:
            print(f"animal.name : {animal.make_sound()} ")
            print(f"{animal.name} :{animal.eat()}")
            print(f"{animal.name}: {animal.sleep()}")
            print("-----------------")

zoo = Zoo()

lion = Mammal("Lion")
parrot =Bird("Parrot")
snake = Reptile("snake")

zoo.add_animal(lion)
zoo.add_animal(parrot)
zoo.add_animal(snake)

zoo.simulate_zoo()

##Abstraction:
#1. What is abstraction in Python, and how does it relate to object-oriented programming?

"""Abstraction is a fundamental concept in computer science and software engineering that involves simplyfying complex system by modeling classes based on the essential properties and behaviours relevant to the problem at hand ,while hiding unnecessary details.

-Abstraction is often achieved through the use of abstract classes and interfaces.
-Abstraction is closely related to encapsulation,which is the bundling of data and methods that operate on that data into a single unit known as a class.
-Abstraction involves modeling high level concepts relevant to the problem domain ,ignoring unnecessary and manageable representation of a system.
-Abstraction promotes code reusability by allowing the creation of generic classes and interfaces that can be extended or implementing by various subclasses.
-polymorphism another key concept is closely related to abstraction .It allows objects of different types to be treated as objects of a common base type.
"""
#2. Describe the benefits of abstraction in terms of code organization and complexity reduction.

"""1.Modularity 
-Abstraction allows developers to break down a complex system into smaller,more manageable modules or classes.
2.CodeReusability 
-Abstract classes and interfaces encourages the creation of generic,reusable components.
3.Encapsulation 
-Abstraction promotews encapsulation ,where the internal details of a module or class are hidden from the outside world.
4.Focus on Essential concepts 
-Abstraction allows developers to focus on the essential aspects of a problem while ignoring unnecessary details.
This makes the codebase more intutive and easier to comprehend,as developers can work with high level concepts rather than getting bogged down by low -level implementation details.
"""
#3. Create a Python class called `Shape` with an abstract method `calculate_area()`. Then, create child classes (e.g., `Circle`, `Rectangle`) that implement the `calculate_area()` method. Provide an example of using these classes.
from abc import ABC, abstractmethod
from math import pi 
class Shape(ABC):
    @abstractmethod
    def calculate_area(self):
        pass

class Circle(Shape):
    def __init__(self,radius):
        self.radius = radius

    def calculate_area(self):
        return pi*self.radius **2
    
class Rectangle(Shape):
    def __init__(self,length,width):
        self.length = length 
        self.width = width 

    def calculate_area(self):
        return self.length * self.width
    
circle = Circle(radius = 5)
rectangle  = Rectangle(length = 5,width = 3)

print(f"Area of circle :{circle.calculate_area():.2f}")
print(f"Area of Rectangle :{rectangle.calculate_area():.2f}")
    

#4. Explain the concept of abstract classes in Python and how they are defined using the `abc` module. Provide an example.

"""In Python, an abstract class is a class that cannot be instantiated and is meant to be subclassed by other classes. Abstract classes are used to define a common interface for a group of related classes, and they often contain abstract methods that must be implemented by their subclasses. Abstract classes provide a way to enforce a certain structure in the subclasses, ensuring that they implement specific methods.

The abc module in Python provides the tools to create abstract base classes (ABCs). The ABC (Abstract Base Class) is a metaclass that allows you to define abstract methods using the @abstractmethod decorator."""
#5. How do abstract classes differ from regular classes in Python? Discuss their use cases.
"""

Abstract classes in Python differ from regular classes in that they cannot be instantiated on their own, and they often include abstract methods that must be implemented by their subclasses. Here are key differences and use cases for abstract classes compared to regular classes:

Abstract Classes:
1.Instantiation:

Abstract classes cannot be instantiated directly. They are meant to be subclassed, and instances are created from the concrete subclasses.
2.Abstract Methods:

Abstract classes often include one or more abstract methods, which are methods without a defined implementation. Subclasses are required to provide concrete implementations for these abstract methods.
3.Use of abc Module:

Abstract classes are typically defined using the abc module in Python. The ABC (Abstract Base Class) metaclass and the @abstractmethod decorator are commonly used to create abstract classes and abstract methods.
4.Enforcement of Structure:

Abstract classes are used to enforce a certain structure in subclasses. They define a common interface that subclasses must adhere to, ensuring a consistent implementation across multiple related classes.
5.Polymorphism:

Abstract classes play a significant role in achieving polymorphism. Objects of different subclasses can be treated as objects of the abstract class type, allowing for a more generalized and flexible code design.
6.Examples:

Examples of abstract classes include a generic Shape class with an abstract method calculate_area(), or an Animal class with abstract methods for make_sound() and move().

Regular Classes:

1.Instantiation:

Regular classes can be instantiated directly. Objects are created from regular classes without the need for subclassing.
2.Concrete Methods:

Regular classes can have both abstract and concrete methods. Concrete methods have defined implementations and provide specific functionalities.
3.No abc Module Usage:

Regular classes do not necessarily rely on the abc module. They can be defined without using abstract methods or the ABC metaclass.
4.Flexibility:

Regular classes provide flexibility in terms of structure and implementation. They may or may not have a predefined structure for subclasses to follow.
.Polymorphism:

While regular classes can also be used in polymorphic scenarios, they do not enforce a common interface in the same way as abstract classes. Polymorphism with regular classes often relies on shared method names and behaviors.
6.Examples:

Examples of regular classes include a Car class with concrete methods for start_engine() and drive(), or a Person class with concrete methods for say_hello() and walk().

Use Cases:
1.Abstract Classes:

Use abstract classes when you want to define a common interface that must be implemented by multiple related classes.
When you want to enforce a certain structure and behavior in subclasses.
When you want to achieve polymorphism by treating objects of different subclasses as objects of a common base type.

2.Regular Classes:

Use regular classes when you need to create standalone objects with specific functionalities.
When you don't need to enforce a specific structure across subclasses.
When you want a class to be instantiated directly without the need for subclassing."""
#6. Create a Python class for a bank account and demonstrate abstraction by hiding the account balance and providing methods to deposit and withdraw funds.

class BankAccount(ABC):
    def __init__(self,account_holder , account_number):
        self.account_holder = account_holder
        self.account_number = account_number
        self._balance = 0

    @abstractmethod
    def show_balance(self):
        pass 
    def deposit(self,amount):
        if amount >0:
            self._balance += amount
            print(f"Deposited rs.{amount}.NEW balance {self._balance}")

        else:
            print(f"Invalid deposit amount.")

    def withdraw(self,amount):
        if 0 < amount <= self._balance:
            self._balance -= amount
            print(f"withdraw amount rs.{amount}.new balance {self._balance}")

        else:
            print("Invalid withdrawl amount")

class Savingaccount(BankAccount):
    def show_balance(self):
        print(f"Account Holder :{self.account_holder} ,Account number : {self.account_number}" )
        print(f"Available balance : rs.{self._balance}")


savings_account = Savingaccount(account_holder= "Rani",account_number=14323423)
savings_account.deposit(10000)
savings_account.withdraw(300)

savings_account.show_balance()
#7. Discuss the concept of interface classes in Python and their role in achieving abstraction.

"""Interface classes are a form of abstraction that allows you to define a contract for classes without providing any implementation .Interface classes play a crucial role in achieving abstraction by specyfying a set of method signature that concrete classes must implement .
While python does not have a built in suntax for explicity defining interfaces,the concept often implementaed using abstract base classes and abstract  method .

KEY CONCEPT 
1.Abstract Base Classes (ABCs):

Abstract base classes in Python are used to define abstract methods, which are methods without a defined implementation. Abstract methods are declared in an abstract base class using the @abstractmethod decorator.
2.Interface Classes:

Interface classes are essentially abstract base classes that declare a set of methods without providing any implementation. They define a contract that concrete classes must adhere to by implementing these methods.
3.Enforcing a Contract:

Interface classes provide a way to enforce a contract between classes. Concrete classes that claim to implement an interface must provide concrete implementations for all the methods declared in the interface.


Achieving Abstraction with Interface Classes:
1.Common Method Signatures:

Interface classes specify common method signatures that participating classes must implement. This ensures a consistent interface across multiple classes, promoting code uniformity and readability.
2.Polymorphism:

Interface classes contribute to achieving polymorphism by allowing objects of different classes to be treated as objects of a common interface type. This enables more flexible and extensible code designs.
3.Code Organization:

Interface classes help organize code by clearly defining the expected behavior of classes that implement them. This separation of concerns makes it easier for developers to understand and maintain the codebase.
4.Use of abc Module:

The abc module in Python is commonly used to create interface classes. The ABC (Abstract Base Class) metaclass, along with the @abstractmethod decorator, facilitates the creation of abstract methods within an interface."""
#8. Create a Python class hierarchy for animals and implement abstraction by defining common methods (e.g., `eat()`, `sleep()`) in an abstract base class.

class Animal(ABC):
    def __init__(self,name,species):
        self.name = name 
        self.species = species
    @abstractmethod
    def make_sound(self):
        pass
    @abstractmethod
    def eat(self):
        pass
    @abstractmethod
    def sleep(self):
        pass

class Mammal(Animal):
    def __init__(self,name,species,fur_color):
        super().__init__(name,species)
        self.fur_color = fur_color

    def make_sound(self):
        return "Mammal sound"
    def eat(self):
        return "Mammal is eating"
    def sleep(self):
        return "Mammal is sleeping"
    
class Bird(Animal):
    def __init__(self,name,species,feather_color):
        super().__init__(name,species)
        self.feather_color= feather_color

    def make_sound(self):
        return "Bird sound"
    
    def eat(self):
        return "Bird is eating"
    def sleep(self):
        return "Bird is sleeping"
    
class Reptile(Animal):
    def __init__(self,name,species,scale_type):
        super().__init__(name,species)
        self.scale_type = scale_type

    def make_sound(self):
        return "Reptile sound "
    
    def eat(self):
        return "Reptile is eating"
    def sleep(self):
        return "Reptile is sleeping"
    

mamal = Mammal(name="lion",species="Mammal",fur_color="Golden")
bird = Bird(name="parrot",species="Bird",feather_color="green")
reptile = Reptile(name="Snake",species="Reptile",scale_type="smooth")

animals = [mamal,bird,reptile]

for animal in animals:
    print(f"{animal.name} ({animal.species})")
    print(f"sound :{animal.make_sound()}")
    print(f"Eating:{animal.eat()}")
    print(f"Sleeping:{animal.sleep()}")
    print(f"-----------")
#9. Explain the significance of encapsulation in achieving abstraction. Provide examples.

"""
1.Data Hiding 
- Encapsulation allows the building of data within a class and restricts access to the internal details of an object.
This is known as data hiding, and it helps in preventing direct manipulation of the object's internal state by external code.
2.Implementation hiding 
- Encapsulation allows for hiding the internal implementation details of a class.
External code  interacts with the class through a well -defined interface, reducing dependencies and making it easier to modify the internal implementation without affecting external code.

3.Abstraction through interface 
-Encapsulation facilitates the creation of well-defined interfaces for classes,providing a level of abstraction.
External code interacts with the class through public methos,abstracting away the internal details.
"""

#example - 

class Car:
    def __init__(self,make,model):
        self.make = make
        self.model = model
        self.__engine_status = "off"
    def start_engine(self):
        self.__engine_status = "On"

    def stop_engine(self):
        self.__engine_status = "off"

my_car = Car("Toyota","Camry")
my_car.start_engine()
#10. What is the purpose of abstract methods, and how do they enforce abstraction in Python classes?

"""Abstract methods in python are methods declared in an abstract base class (ABC) using the @abstracrtmethod decorator but they do not provide an implementation.
Their purpose is to serve as a blueprint for subclasses ,ensuring  that all derived classes must procvide their own implementation for these abstract methosds.

Purpose of abstract method
1.Define a common interface 
Abstract method allow you to  define a common set of methods that must be implemented by all concrete subclasses.
This helps establish a consistent interface for a group of related classes.

2.Force subclasses to provide implementation 
-Subclasses that inherit from an abstract base class are required to implement all the abstracrt methods declared in that class.This ensures that each subclass provides its own specific implementation,promotinf code consistency.

3.Enforce Design Contracts 
-Abstract methods help enforce design contracts, ensuring that certain methods are availaible in all subclasses.
This is especially useful in scenarios where a shared interface or behavior is expected across multiple classes.

HOW ABSTRACT METHDS ENFORCE ABSTRACTION 
1.Template for subclasses:
-Abstract method act as a template or blueprint for subclass.They define the expected methods that subclasses must implement but leave the implementation details to the individual subclasses.

2.Runtime Checks :
-If a subclass fails to provide an implementation  for any abstract method ,attempting to instantiate an object of that subclass will result in a typeerror .
This runtime checls enforces that all abstract methods are implemented before the class can be instantiated .

3.Forces Subclass Specificity 
-Abstract method forces subclass to be specific about their  implementation details.This specificity helps in  achieving  a higher level of abstraction by allowing the base class to define the overall structure while leaving the detailed behaviour to the subclass.
"""
#11. Create a Python class for a vehicle system and demonstrate abstraction by defining common methods (e.g., `start()`, `stop()`) in an abstract base class.

class Vehicle(ABC):
    def __init__(self,brand ,model):
        self.brand = brand
        self.model = model

        @abstractmethod
        def start(self):
            pass

        @abstractmethod
        def stop(self):
            pass

class Car(Vehicle):
    def __init__(self,brand,model,fuel_tupe):
        super().__init__(brand,model)
        self.fuel_tupe = fuel_tupe
        self.engine_running = False

    def start(self):
        if not self.engine_running:
            print(f"{self.brand} {self.model}'s engine started")
            self.engine_running = True 
        else:
            print(f"{self.brand} {self.model}'s engine is already running")

    def stop(self):
        if self.engine_running :
           print(f"{self.brand} {self.model}'s engine stopped.")
           self.engine_running = False

        else:
            print(f"{self.brand} {self.model}'s engine is already stopped")

class Bicycle(Vehicle):
    def __init__(self,brand,model ,bike_type):
        super().__init__(brand,model)
        self.bike_type = bike_type

    def start(self):
        print(f"{self.brand} {self.model} doesn't have  an engine but can be padable")
    
    def stop(self):
        print(f"{self.brand} {self.model} doesn't hava an engine to stop.")


car = Car(brand="Toyota" ,model="Camry",fuel_tupe="petrol")
bike = Bicycle(brand="Trek",model= "mountain bike" ,bike_type= "off road")

car.start()
bike.start()
car.stop()
bike.stop()





#12. Describe the use of abstract properties in Python and how they can be employed in abstract classes.

"""In python , abstract properties are properties declared in abstract base classes(ABC) using the @property  decorator along with the  @abstractmethod  deorator .Abstract properties are used to define a common  interface for attributes that must be implemented by concrete subclasses.

USE OF ABSTRACT PROPERTIES IN ABSTRACT CLASSES :
1.Common interface for attributes 
- Abstract properties provide a way to define a common interface for attributes that must be  present in concrete subclasses.

2.Foring subclasses to define properties 
-Subclasses that inherit from an  abstract base class with abstract properties are required to provide their own implementation for those properties.This ensures that instances of the  derived classes will have the necessary attributes.

3.Read only calculated properties 
-Abstract properties can be used to define read -only or calculated properties that rely on other attributes or methods in the class. This allow for a flexible and abstract way to define attributes that might depend on the internal state of the class.

"""
#13. Create a Python class hierarchy for employees in a company (e.g., manager, developer, designer) and implement abstraction by defining a common `get_salary()` method.

class Employee(ABC):
    def __init__(self,name,employee_id):
        self.name = name 
        self.employee_id = employee_id

    @abstractmethod
    def get_salary(self):
        pass

class Manager(Employee):
    def __init__(self,name,employee_id,base_salary,bonus):
        super().__init__(name,employee_id)
        self.base_salary = base_salary
        self.bonus = bonus

    def get_salary(self):
        return self.base_salary + self.bonus
    

class Developers(Employee):
    def __init__(self,name,employee_id,base_salary,coding_language):
        super().__init__(name,employee_id)
        self.base_salary= base_salary
        self.coding_language = coding_language

    def get_salary(self):
        return self.base_salary+ len(self.coding_language) *1000
    
class Designer(Employee):
    def __init__(self,name,employee_id,base_salary,years_of_experience):
        super().__init__(name,employee_id)
        self.base_salary = base_salary
        self.years_of_experience = years_of_experience

    def get_salary(self):
        return self.base_salary+ self.years_of_experience *500
    

manager = Manager(name = "jane",employee_id=101,base_salary=80000,bonus=10000)
developer= Developers(name="ani", employee_id=102,base_salary= 50000,coding_language=["python","java"])
designer = Designer(name= "bobby",employee_id=103,base_salary=50000,years_of_experience=2)

employees = [manager,developer,designer]

for employe in employees:
    print(f"{employe.name} (Id: {employe.employee_id})")
    print(f"salary:rs.{employe.get_salary()}")
    print()


#14. Discuss the differences between abstract classes and concrete classes in Python, including their instantiation.

"""
Abstract classes 
1.Abstract classes are classes that cannot be instantiated on their own .
They serve  as blueprint for other classes and may contain methods that must be implemented by their subclasses.

2.Purpose 
- The  primary purpose of abstract classes is to provide a common interface for a group of relate classes .
They define a set of methods that must be implemented by the subclasses,enforcing a certain structure across the subclasses.

3.Instantiation 
-Abstract classes cannot be instantiated directly .
Attempting to create an instance of an abstract class will result in a Typeerror .


Concrete class :
1.Concrete classes are classes that can be instantiated directly.They may inherit from abstract classes or other concrete classes and provide concrete methods.

2.Purpose 
-The purpose of concrete classes is to provide specific implementation of methods.
They can be instantiated and their instances can be used directly in the program.

3.Instantiation 
-Concrete classes can be instantiated using the ClassName syntax .Instances of concrete classes can be created and used as objects in your program .
"""
#15. Explain the concept of abstract data types (ADTs) and their role in achieving abstraction in Python.

""" Abstract Data Types are a high-level conceptual model that defines  a set of operations on data , without specifying the underlying implementation details.
ADTs are essential for achieving abstraction in  programming , allowing developers to focus on the functionality and behavior of data structure without concerning themselves with how the operations are implemented.

Key concepts - 
1.Abstraction - 
ADTs  encapsulate complex data structure and their association operations, providing a clear and abstract interface to users.
This abstraction allows developers to use data structures without being concerned about the internal implementation details.

2.Encapsulation 
-ADTs  encapsulate both the data and the operations that can be performed on the data within a single unit.
This helps in hiding the complexity of the implementation and exposing only the necessary functionality.

3.Data and Operations 
-An ADT define a set of data operations on that data.
The data can be primitive types or more complex structures and the operations can include functions or methods that manipulate the data .

4.Separation of Concerns 
-ADTs allow  for a clear separation of concerns between the user of the data structure and the implementer.
Users interact with the abstract interface,while implementers focus on the details of how the operations are performed.

ROLE --->
1.Definin Interfaces 
-ADTs help in defining clear and consistent interfaces for data structure .
This involves specify the methods or functions that can be used to interact with the data without revealing the internal details.

2.Implemenation Independence-
-Users can rely on the abstract interface provided by an ADT without worrying about how the operations are implemented.
This independence allows for flexibility in changing or upgrading implementation without affecting the code using the ADT.

3.Code Reusability 
-ADTs  promote code reusability by providing well - defined interfaces that can be reused across different projects .Once an ADT is implemented,it can be utilized in various contexts without modification ,as long as the abstract interface remains consistent
"""
#16. Create a Python class for a computer system, demonstrating abstraction by defining common methods (e.g., `power_on()`, `shutdown()`) in an abstract base class.

class ComputerSystem(ABC):
    def __init__(self,brand,model):
        self.brand = brand
        self.model = model
        self.powered_on = False
    @abstractmethod
    def Power_on(self):
        pass

    @abstractmethod
    def shutdown(self):
        pass

    @abstractmethod
    def restart(self):
        pass

class DesktopComputer(ComputerSystem):
    def __init__(self,brand,model,monitor_size):
        super().__init__(brand,model)
        self.monitor_size = monitor_size

    def Power_on(self):
        if not self.powered_on:
            print(f"{self.brand} {self.model} desktop is poweing on.")
            self.powered_on = True

        else:
            print(f"{self.brand} {self.model} desktop is already powered on.")

    def shutdown(self):
        if self.powered_on:
            print(f"{self.brand} {self.model} desktop is shutting down ")
            self.powered_on = False
        else:
             print(f"{self.brand} {self.model} desktop is already powered off.")

    def restart(self):
        self.shutdown()
        self.Power_on()

class Laptop(ComputerSystem):
    def __init__(self,brand,model,screen_size):
        super().__init__(brand,model)
        self.screen_size = screen_size 
        self.battery_level = 100

    def Power_on(self):
        if not self.powered_on:
            print(f"{self.brand} {self.model} laptop is powering on ")
            self.powered_on = True
        else:
            print(f"{self.brand} {self.model} laptop is already powered on ")

    def shutdown(self):
        if self.powered_on:
            print(f"{self.brand} {self.model} laptop is shutting down.")
            self.powered_on = False
        
        else:
            print(f"{self.brand} {self.model} laptop is already powered off.")

    def restart(self):
        self.shutdown()
        self.Power_on()


desktop = DesktopComputer(brand="Dell",model="Inspiron",monitor_size="24 inches")
laptop  = Laptop(brand="Hp" ,model="Pavilion",screen_size="15.6 inches")

desktop.Power_on()
desktop.shutdown()
desktop.restart()

laptop.Power_on()
laptop.shutdown()
laptop.restart()

#17. Discuss the benefits of using abstraction in large-scale software development projects.

"""
BENEFITS - 
1.Modularity and Encapsulation 
-Abstractio allows breaking down a large system into smaller,manageable modules.
Each module encapsulates a specific set of functions and hides the implementation details.

2.Reduced complexity 
-Abstraction helps manage and reduce complexity by providing a high-level view of the system.
Developers can focus on the essential features and interactions without being overwhelmed by the intricate details of every component.

3.Code Reusability 
-Abstract promotes code reusability by defining generic interfaces and classes that can be utilized across different parts of the software or even in other project.

4.Ease of Maintenance 
-Abstraction away implemention details makes maintenance tasks more straightforward .
Changes to the underlying implementation can be made without affecting the overall functionality ,as long as the abstract interfaces remain consistent.

5.Scalibility 
-Abstraction facilitates scalability by providing a foundation for extending the system with new features or accommadating increased data and user loads.
New functionality can be added by creating new classes or modules that adhere to the existing abstract interfaces ,ensuring compatibility and coherence.
"""
#18. Explain how abstraction enhances code reusability and modularity in Python programs.

"""
Code Reusability 
1.Defined interfaces 
-Abstraction allows you to define clear and standardized interfaces for classes and functions.
By exposing only essentials methods and properties ,you create a contract that can be easily reused.

2.Generic Implementation 
-Abstract classes of functions can be provide generix implementation that work for a wide range of scenarios .Subclasses or specific implementation can then inherit or utilize these generic structures ,promoting code reuse.

3.Library and Framework Usage :
Python has  a rich ecosystem of libraries and frameworks that leverage abstraction .When you use these external tools,you are essentially reusing abstracted Code.

Modularity - 
1.Encapsulation -
Abstraction and encapsulation go hand in hand.By encapsulating implementation details within classes or modules, you create self -contained units of functionality.
This encapsulation promotes modularity by hiding the internal complexities and exposing only the necessary interface.

2.Seperation of Concerns -
Abstraction encourages the seperation of concerns by dividing a program into distinct,independent modules.

3.Clear interface 
Abstraction defines clear and well-defined  interfaces between differenrt modules.
Modules interact through these interfaces,and the internal details are abstracted away.

"""
#19. Create a Python class for a library system, implementing abstraction by defining common methods (e.g., `add_book()`, `borrow_book()`) in an abstract base class.

class LibrarySystem(ABC):
    def __init__(self,name):
        self.name = name
        self.books = {}

    @abstractmethod
    def add_book(self,title,author):
        pass
    @abstractmethod
    def borrow_book(self,title):
        pass

    @abstractmethod
    def return_book(self,title):
        pass

    def list_books(self):
        if not self.books:
            print("No books in the library")

        else:
            print("Books availaible in the library")
            for title ,author in self.books.items():
                print(f"{title} by {author}")

class SimpleLibrary(LibrarySystem):
    def add_book(self, title, author):
        if title not in self.books:
            self.books[title] = author
            print(f"Added'{title}' by {author} to the library")

        else:
            print(f"BOOK '{title}' already exists in the library")

    def borrow_book(self, title):
        if title in self.books:
            print(f"Borrowed '{title}' from the library")
            del self.books[title]

        else:
            print(f"Book '{title}' is not availaible in the library ")

    def return_book(self, title):
        if title not in self.books:
            self.books[title] = author
            print(f"Returned '{title}' to the library.")
        else:
            print(f"Book '{title}' was not borrowed from the library.")
simple_library = SimpleLibrary(name="Simple Library")
simple_library.list_books()

simple_library.add_book(title = " the green land" ,author ="d.doxy")
simple_library.add_book(title="the girl dream",author = "devadhish sardana")
simple_library.list_books()

simple_library.borrow_book(title="the green land")
simple_library.list_books()

simple_library.return_book(title = "the girl dream")
simple_library.list_books()
#20. Describe the concept of method abstraction in Python and how it relates to polymorphism.
""" Method Abstraction 

1.Abstract through abstract methods 
Abstraction methods are declared in an abstract base class(ABC) using the @abstractmethod  decorator .
These  methods are method to be implemented by concrete subclasses.THey provide a common interface that enforces derived classes to provide their own implementation .

2.Polymorphic Behavior
Abstraction methods in an abstract base class allow different subclsses to implement those methods on their own way.


POLymorphism 

1.Multiple implementation 
In polymorphism a single method name can used to represent  multiple implementation across different classes.
This enables  code to be more flexible and adaptable,as objects of different types can respond to the same method calls 

2.Usage of common interface 
Polymorphism allows code to use objects of different classes interchangeably , as long as they adhere to a common interface.
 """

##Composition 
#1. Explain the concept of composition in Python and how it is used to build complex objects from simpler ones.

"""
IN python,composition is a design principle that allow you to create complex object by combining simple ones.
It is one of the fundamental concepts of oop and promote code reusability , maintainability ,and flexibility.
Composition is an alternative to inheritance,where instead of creating complex objects through the hierarchy of classes,you build them by assembling or composing simpler objects.

The main idea behind composition is to create relationship between objects by including instances of one class within another class.
This is typically achieved through attributes that hold references to other objects.

"""
#2. Describe the difference between composition and inheritance in object-oriented programming.

"""
Composition 
1.Relationship 
-In composition ,the relationship between classes is based on including instances of one class within another class.
This typically achieved through attributes that hold references to other objects.

2.Code Reusability 
-promotes code reusability by allowing you to build complex objects by assembling simpler ones.
You can reuse and interchange components easily as they are seperate entities.

3.flexibility 
-Provides greater flexibility compared to inheritance.
You can easily change or extend the behaviour of a class by modifying its component or adding new ones without affecting the entire class hierarchy .


Inheritance 
1.Relationship
-Inheritance involves creating a hierarchy of classes,where a derived class inherits attributes and  methods from a base class.
The derived class is a specialized version of the base classs.

2.Code Reusability 
-Promotes code reusability by allowing you to inherit and reuse the functionality of existing classes.Derived classes can use or override methods and attributed of the base class.

3.Flexibility 
-Can lead to a more rigid structure . Changes in the base class may affect all derived classes, and modifying the hierarchy can be more challenging without introducing issues.
"""
#3. Create a Python class called `Author` with attributes for name and birthdate. Then, create a `Book` class that contains an instance of `Author` as a composition. Provide an example of creating a `Book` object.

class Author:
     def __init__(self,name,birthdate):
         self.name = name 
         self.birthdate = birthdate 

class Book:
    def __init__(self,title,author,publication_year):
        self.title = title
        self.author = author 
        self.publication_year = publication_year

    def display_info(self):
        author_info = f"Author:{self.author.name},Birthdate :{self.author.birthdate} "
        book_info = f"Title :{self.title},Published:{self.publication_year}"
        return f"{author_info}/n{book_info}"
    

author = Author(name="ani",birthdate="january 2,2000")
book = Book(title="sample book",author=author,publication_year=2022)

print(book.display_info())
#4. Discuss the benefits of using composition over inheritance in Python, especially in terms of code flexibility and reusability.

"""
1.Modualrity and Flexibility
-Composition allows for a more  modular design.You can build complex objects by combining simple ones,making it easier to understand ,modify ,and extend the codebase.

_Components are loosely coupled,providing flexibility in terms of adding ,removing,or modifying functionality without affecting the entire system.

2.Code Reusability 
-composition promotes code reusability by encouraging the creation of smaller, self-contained classes that can be easily reused in different contexts.
-objects can be composed of other objects, and these smaller components can be reused in various combinations to build different complex objects.

3.Avoiding the Diamond problem 
-The diamond problem occurs in language that support multiple inheritance when a class inherits from two classes that have a common ancestor .
This can lead to ambiguity and maintenance challenges.

4.Reducing Coupling 
-Composition reduces class coupling ,making classes more independent .Changes in one class are less likely to affect other classes ,promoting a more maintainable and scalable codebase.
 """
#5. How can you implement composition in Python classes? Provide examples of using composition to create complex objects.

class Engine:
    def start(self):
        return "Engine started"
    
class Car:
    def __init__(self,engine):
        self.engine = engine

    def start(self):
        return f"Car started .{self.engine.start()}"
    
my_engine = Engine()
my_car = Car(engine = my_engine)

result = my_car.start()
print(result)
#6. Create a Python class hierarchy for a music player system, using composition to represent playlists and songs.

class Song:
    def __init__(self,title,artist,duration):
        self.title = title
        self.artist = artist 
        self.duration = duration

    def play(self):
        return f"Now Playing :{self.title} by {self.artist}"
    
class Playlist:
    def __init__(self,name):
        self.name = name
        self.songs =[]

    def add_songs(self,song):
        self.songs.append(song)

    def play_all(self):
        if not self.songs:
            return "Playlist is empty"
         
        Playlist_info = f"Playlist :{self.name}\n"
        song_info = "\n".join(song.play() for song in self.songs)
        return f"{Playlist_info}{song_info}"

class MusicPlayer:
    def __init__(self):
        self.playlists = []

    def create_playlist(self,name):
        playlist = Playlist(name)
        self.playlists.append(playlist)
        return playlist
    
    def play_all_playlists(self):
        if not self.playlists:
            return "No playlist availaible"

        all_playlist_info = "\n\n".join(playlist.play_all() for playlist in self.playlists)
        return f"All Playlists :\n{all_playlist_info}"


song1 = Song(title="Song1",artist="Artiist 1",duration = "3:30") 
song2 = Song(title="Song2",artist="Artiist 2",duration = "4:30") 
song3 = Song(title="Song3",artist="Artiist 3",duration = "2:30") 

playlist1 = Playlist(name="myplaylist 1 ")
playlist1.add_songs(song1)
playlist1.add_songs(song2)

playlist2 = Playlist(name="MyPlaylist2")
playlist2.add_songs(song2)
playlist2.add_songs(song3)


music_player = MusicPlayer()
music_player.create_playlist(name="favorite")
music_player.create_playlist(name="chill Mix")

result = music_player.play_all_playlists()
print(result)
#7. Explain the concept of "has-a" relationships in composition and how it helps design software systems.

""" HAS - A RELATIONSHIP IN COMPOSITION
1.Comosition 
- Has-a relationship are implemented using composition ,where one class holds an instance of another class .
-The composite class is composed of one or more components,and the relationship between them represents a has-a association.

2.Modularity and Reusability 
-By composing objects through a has-a relationship, code become more modular .Smaller ,self-contained classes can be created, and these classes can be reused in various contexts.
-Each class encapsulates a specific functionality or represents a distinct concept,making it easier to understand ,maintain ,and modify .

3.Flexibility and Maintainability 
-The has-a relationship enhances the flexibility of the software system .Changes to one class or component do not necessarily impact other parts of the system.
-It allows for easier maintenance, as modifications to one class can be made independently without affecting the entire codebase.
"""
#8. Create a Python class for a computer system, using composition to represent components like CPU, RAM, and storage devices.

class CPU:
    def __init__(self,brand,model,clock_speed):
        self.brand = brand
        self.model = model
        self.clock_speed = clock_speed

    def process_data(self):
        return "Cpu processing data "
    
class RAM:
    def __init__(self,capacity,speed):
        self.capacity = capacity
        self.speed = speed 

    def store_data(self):
        return "RAM storing data "


class StorageDevice:
    def __init__(self,type,capacity):
        self.type = type 
        self.capacity = capacity

    def read_data(self):
        return "Storage device reading data "

class ComputerSystem:
    def __init__(self,cpu,ram,storage_davice):
        self.cpu  = cpu 
        self.ram = ram 
        self.storage_davice = storage_davice 

    def perform_computingtask(self):
        cpu_result = self.cpu.process_data()
        ram_result = self.ram.store_data()
        storage_result = self.storage_davice.read_data()
        return f"Computer System performing task :\n {cpu_result}\n{ram_result}\n{storage_result}"
    
my_cpu = CPU(brand="INtel",model="i7" ,clock_speed="3.5 ghz")
my_ram = RAM(capacity="16gb",speed="2400Mhz")
my_storagedevice = StorageDevice(type = "SSd",capacity="512 GB")

my_computer = ComputerSystem(cpu = my_cpu,ram=my_ram,storage_davice=my_storagedevice)
result = my_computer.perform_computingtask()
print(result)
#9. Describe the concept of "delegation" in composition and how it simplifies the design of complex systems.

"""
Delegation in the context of composition refers to the act of assigning responsibility for a particular task or behavior to another object.
It is design principle where one object passes a task to another object to perform.

1.Seperation Concern 
-Delegation promotes the seperation of concerns by assigning specific tasks or responsibilities to individual objects.
Each object focusses on a particular aspect of functionality,making the overall system more modular and easier to understand.

2.Code Reusability 
-Delagation encourages the reuse of existing components.Objects can be reused in different context because they encapsulate specific functionality and cn be easily composed into various  configuration .

3.Flexibility and Adaptability 
-Delegation allows for dynamic changes in behaviour without modyfying the delegator .
The delegate can be changed or replaced at runtime,providing flexibility and adaptabillity to evolving requirements.

4.Encapsulation 
-Delegation enhances encapsulation by hiding the internal details of a task within the delegate.
The delegator only needs to know that the delegate can perform a specific tasks without being concerned about the implementation details.
"""
#10. Create a Python class for a car, using composition to represent components like the engine, wheels, and transmission.

class Engine:
    def __init__(self,fuel_type,horsepower):
        self.fuel_type = fuel_type
        self.horsepower = horsepower

    def start(self):
        return "Engine Started"
    
class transmission:
    def __init__(self,transmission_type):
        self.transmission_type = transmission_type

    def shift_gear(self):
        return "Gear Shifted"
    
class Wheel:
    def __init__(self,position):
        self.position = position
    def rotate(self):
        return "wheel rotating"
    
class Car:
    def __init__(self,engine,transmission,wheels):
        self.engine = engine
        self.transmission = transmission
        self.wheels = wheels

    def start(self):
        engine_result = self.engine.start()
        transmission_result = self.transmission.shift_gear()
        wheels_result = ", ".join(wheel.rotate() for wheel in self.wheels)
        return f"Car Started :\n{engine_result} \n{transmission_result}\n{wheels_result}"
    

my_engine = Engine(fuel_type= "GAsoline",horsepower=200)
my_transmission = transmission(transmission_type="Automatic")
my_wheels = [Wheel(position = "Front Left"), Wheel(position= "Front Right"), Wheel(position = "Rear Left"),Wheel(position = "Rear Right")]

my_car = Car(engine = my_engine,transmission=my_transmission,wheels=my_wheels)

result = my_car.start()
print(result)
#11. How can you encapsulate and hide the details of composed objects in Python classes to maintain abstraction?

"""Encapsulation is a fundamenal principle of oop and it involves bundling the data(attributes) and the method that operate on the data into a single unit,
often referred to as a class.IN the context of composed objects,encapsulation helps in hide the internal details of the objects,promoting abstraction and allowing changes to the implementation without affecting the rest of the code.

1.Use Private Attributes
-Declare attributes as private by prefixing them with a double underscore .This convention makes the attribute harder to access from outside the class,
effictively encapsulating them.

2.Provide public method
-Create public method that act as interface with the composed objects.
These methods encapsulate the internal details and provide a clear way to internal with the object.

3.Hide complex logic 
-If the coresponds objects have complex logic or interactions,encapsulae that logic within the class methods.
The external code only needs to call these methods without knowing the intricate details.

4.Use Getters and Setters 
-if you need to expose certain attributes but want control over access or modification ,use getters and setters.This allow you to encapsulate the attribute acess and modification logic.
"""
#12. Create a Python class for a university course, using composition to represent students, instructors, and course materials.

class Student:
    def __init__(self,student_id,name):
        self.student_id = student_id
        self.name = name
    
    def enroll(self,course):
        course.add_student(self)
        return f"{self.name}enrolled in {course.course_name}"
    
class Instructor:
    def __init__(self,instructor_id,name):
        self.instructor_id = instructor_id
        self.name = name 

    def assign_course(self,course):
        course.set_instructor(self)
        return f"{self.name} assign as the instructor for {course.course_name}"
    
class CourseMaterial:
    def __init__(self,textbook,syllabus):
        self.textbook = textbook
        self.syllabus = syllabus

class Universitycourse:
    def __init__(self,course_name,course_code):
        self.course_name = course_name
        self.course_code = course_code
        self.students = []
        self.instructor = None
        self.course_material = None

    def add_student(self,student):
        self.students.append(student)

    def set_instructor(self,instructor):
        self.instructor = instructor

    def set_course_material(self,course_material):
        self.course_material = course_material

    def display_course_info(self):
        students_info =[f"{student.name} (ID:{student.student_id})" for student in self.students]
        instructor_info = f"Instructor :{self.instructor.name} (ID :{self.instructor.instructor_id})"
        course_material_info = f"Course Material :Textbook - {self.course_material.textbook},syllabus - {self.course_material.syllabus}"

        return f"\nCourse Information for {self.course_name} ({self.course_code}) : \n"\
                f"Students :{','.join(students_info)}\n" \
                f"{instructor_info}\n"\
                f"{course_material_info}"
    
student1 = Student(student_id=1,name="diya")
student2 = Student(student_id=2,name="Boby")

instructor1 = Instructor(instructor_id=101,name="prof.sui")

material = CourseMaterial(textbook="Introduction to Python",syllabus="Weak by Weak")

python_course = Universitycourse(course_name="PythonProgramming",course_code="cs101")

python_course.set_course_material(material)

student1.enroll(python_course)
student2.enroll(python_course)

instructor1.assign_course(python_course)

course_info = python_course.display_course_info()
print(course_info)
#13. Discuss the challenges and drawbacks of composition, such as increased complexity and potential for tight coupling between objects.

"""Drawbacks --->
1.Increased Complexity 
-Composition can lead to increased complexity , especially in systems with deep hierarchies of composed objects.
Managing the relationships and interactions between various components can become intricate.

2.Potential for tight coupling 
-Although composition is intended to promote loose coupling, improper design can lead to tight coupling between objects .
If one object relies heavily on the internal details of another object,changes in one component may require modifications in others,defeating the purpose of composition.

3.Boilerplate Code 
-As you compose more objects ,you may fine yourself writing boilerplate code to delegate method calls or manage interactions between components.This can result in redundant code that may be error- prone and harder to maintain .

4.Dependency Management
-Mananging dependencies between objects can become challenging .If a component relies on multiple other components,ensuring that they are all availaible and properly initialized can be a non-trivial task.
"""
#14. Create a Python class hierarchy for a restaurant system, using composition to represent menus, dishes, and ingredients.

class Ingredient:
    def __init__(self,name,quantity,units):
        self.name = name 
        self.quantity = quantity 
        self.units = units

class Dish:
    def __init__(self,name,description ,ingredients):
        self.name = name 
        self.description = description
        self.ingredients = ingredients

    def display_dish(self):
        ingredient_list = [f"{ingredient.quantity} {ingredient.units} of {ingredient.name}" for ingredient in self.ingredients]
        return f"{self.name}\Description :{self.description}\nIngredients :{', '.join(ingredient_list)}"
    

class Menu:
    def __init__(self,name,dishes):
        self.name = name 
        self.dishes = dishes
    
    def add_dish(self,dish):
        self.dishes.append(dish)
    
    def display_menu(self):
        return f"\nMenu:{self.name}\n" + "\n".join(dish.display_dish() for dish in self.dishes)

class Restaurant:
    def __init__(self,name,menus):
        self.name = name 
        self.menus = menus

    def add_menu(self,menu):
        self.menus.append(menu)

    def display_restaurant_info(self):
        return f"Restaurant :{self.name}\n" + "\n".join(menu.display_menu() for  menu in self.menus)
    

ingredient1 = Ingredient(name ="Tomato",quantity=2,units = "pieces")
ingredient2 = Ingredient(name="cheese",quantity = 150,units = "grams")
ingredient3 = Ingredient(name = "flour",quantity=200,units="grams")
ingredient4 = Ingredient(name="paneer" ,quantity=250,units="grams")


pizza = Dish(name="Margherita Pizza",description="classic margherita pizza with tomato and cheese",ingredients=[ingredient1,ingredient2])
pasta = Dish(name = "paneer pasta ",description="creamy paneer pasta",ingredients=[ingredient3,ingredient4])

italian_menu = Menu(name="italian cusine",dishes =[pizza,pasta])

my_restaurant = Restaurant(name="OM restaurant",menus =[italian_menu])

restaurant_info = my_restaurant.display_restaurant_info()

print(restaurant_info)
#15. Explain how composition enhances code maintainability and modularity in Python programs.

"""
Compositio enhance code maintainability and modularity in python programs by promoting a design approach that amphasize building complex systems from smaller,independent components.

1.Modularity 
-Composition allows you to break down a system into smaller,self-contained modules or components.
Each component focuses on a specific  aspect of functionality ,making the codebase modular and easier to understand.

2.Code Reusability 
-With composition ,individuals components can be reused in different contexts.
This is particularly beneficial when you have well -defined ,reusable pieces of functionality that can be leverged across multiple parts of your program or even in diggerent projects.

3.Encapsulation 
-Composition encourages encapsulation,which is the building of data and functionality into a  single unit .The internal details of a component are hidden from the outside world,
promoting a clear interface and reducing the risk of unintended interference.

4.Flexibility and Extensibility
-Components created through composition are typically designed with clear interfaces.
This makes it easier to modify or extend the system without affecting other parts of the code.
New components can be added ,and existing ones can be modified without causing ripples effects throuhout the entire codebase.

5.Ease of testing 
-Individuals components can be tested independently,allowing for more focused and effective testing .This is particularly advantageous in unit testing,where you can isolate and test each module in isolation ,ensuring that it functions correctly before integrating it into the larger system.
"""
#16. Create a Python class for a computer game character, using composition to represent attributes like weapons, armor, and inventory.

class Weapon:
    def __init__(self,name,damage):
        self.name = name
        self.damage = damage

class Armor:
    def __init__(self,name,defence):
        self.name = name 
        self.defence = defence

class Inventory:
    def __init__(self):
        self.items =[]

    def add_item(self,item):
        self.item.append(item)

class Gamecharacter:
    def __init__(self,name ,health,weapon =None ,armor = None):
        self.name = name 
        self.health = health
        self.weapon = weapon 
        self.armor = armor
        self.inventory = Inventory()

    def equip_weapon(self,weapon):
        self.weapon = weapon

    def equip_armor(self,armor):
        self.armor = armor

    def take_damage(self,damage):
        if self.armor:
            damage -= self.armor.defence
            damage = max(0,damage)

        self.health -= damage
        print(f"{self.name} took {damage} damage. Current health:{self.health}")

    def attack(self,target):
        if self.weapon:
            print(f"{self.name} attacks {target.name} with {self.weapon.name} for {self.weapon.damage} damage.")
            target.take_damage(self.weapon.damage)

        else:
            print(f"{self.name} attacks {target.name} for 1 damage.")
            target.take_damage(1)


sword = Weapon("Sword ",10)
shield = Armor("shield",5)

player = Gamecharacter("player",100,sword,shield)

enemy = Gamecharacter("Enemy",50)
player.attack(enemy)
enemy.attack(player)





#17. Describe the concept of "aggregation" in composition and how it differs from simple composition.

"""
Composition 
-In composition , one class contains an instance of  another class and  is responsible for the creation and destruction of the contained objects.
This means that the contained object is a part  of the whole, and when the containig object is destroyed ,the contained object is also destroyed.
composition is often used when there is a strong  has-a relationship between the containnig and contained objects.

Aggregation 
-Aggregation ,on the other hand ,is a more loosely coupled relationship .It occurs when one class contains another class, but the contained object has an independent lifecycle and can exit without the containing object.
The contained object is not fully owned by the containig object,and it can be shared among multiple containing objects .
"""
#18. Create a Python class for a house, using composition to represent rooms, furniture, and appliances.

class Furniture:
    def __init__(self,name):
        self.name = name
class Appliance:
    def __init__(self,name):
        self.name = name

class Room:
    def __init__(self,name):
        self.name = name
        self.furniture =[]
        self.appliances =[]

    def add_furniture(self,furniture):
        self.furniture.append(furniture)
        
    def add_appliance(self,appliance):
        self.appliances.append(appliance)

class House:
    def __init__(self,address):
        self.address = address
        self.rooms =[]

    def add_room(self,room):
        self.rooms.append(room)

living_room = Room("Living Room")
sofa = Furniture("Sofa")
tv = Appliance("TV")
living_room.add_furniture(sofa)
living_room.add_appliance(tv)

kitchen = Room("Kitchen")
table = Furniture("Dining Table")
oven = Appliance("Oven")
kitchen.add_furniture(table)
kitchen.add_appliance(oven)

my_house = House("123 Main Street")
my_house.add_room(living_room)
my_house.add_room(kitchen)

# Accessing objects within the house
for room in my_house.rooms:
    print(f"\n{room.name}:")
    print("Furniture:")
    for furniture in room.furniture:
        print(f"  - {furniture.name}")
    print("Appliances:")
    for appliance in room.appliances:
        print(f"  - {appliance.name}")
#19. How can you achieve flexibility in composed objects by allowing them to be replaced or modified dynamically at runtime?

"""
Using Interfaces or Abstract classes:
Define interfaces or abstract classes for the components that can be composed.
This allows for the interchangeability of different implementations.Clients interact with these components through their interfaces,making ita easy to replace or modify implementation at runtime.

2.Dependency Injection 
Use dependency injection to provide components to an object at runtime.This way,you can easily replace or modify the components without modify the object's code  .
This enhances the flexibility of the composed object.
3.Decorator Pattern 
Use the decorator pattern to dynamically add or replace responsibility of objects.
This allows you to stack multiple decorators on an object,and each decorator can modify the behaviour of add functionality .

"""
#20. Create a Python class for a social media application, using composition to represent users, posts, and comments
class Comment:
    def __init__(self ,user, text):
        self.user = user
        self.text= text 

    def __str__(self):
        return f"{self.user.username} : {self.text}"
    
class Post:
    def __init__(self,user,content):
        self.user = user
        self.content = content
        self.comments =[]

    def add_comment(self,user,text):
        comment = Comment(user,text)
        self.comments.append(comment)

    def display_comments(self):
        for comment in self.comments:
            print(comment)

    def __str__(self):
        return f"{self.user.username} posted:{self.content}"
    
class User:
    def __init__(self,username,name):
        self.username = username
        self.name = name 
        self.posts =[]

    def create_post(self,content):
        post = Post(self,content)
        self.posts.append(post)
        return post
    
    def __str__(self):
        return f"{self.name}({self.username})"
    

# Create users
user1 = User("john_doe", "John Doe")
user2 = User("jane_smith", "Jane Smith")

# Users create posts
post1 = user1.create_post("Hello, world!")
post2 = user2.create_post("Enjoying a beautiful day.")

# Users add comments to posts
post1.add_comment(user2, "Nice post!")
post2.add_comment(user1, "Thanks! It's a lovely day indeed.")

# Display posts and comments
print(f"{user1}'s Posts:")
for post in user1.posts:
    print(post)
    post.display_comments()

print(f"\n{user2}'s Posts:")
for post in user2.posts:
    print(post)
    post.display_comments()
# Out:
# Area ofCircle :50.27
# Area ofsquare :64.00
# starting the 4 - door car :Toyotacamry
# padaling the Schwin mountain Bike bicycle with 21 gears.
# Starting the boat :Sea Ray sudancer with 2 engines.
# storing data locally :sample data
# Uploading data to the cloud : sample data
# Area of the shape :78.54
# Area of the shape :15.00
# Area of the shape :7.00
#
# Account Type: Savingaccount
# Withdrawl of rs.205 successful.Remaining balance : rs.795
# Penalty of 5 applied for withdrawing from saving account.
#
# Account Type: checkingAccount
# Withdrawl of rs.200 successful.Remaining balance : rs.1800
#
# Account Type: Creditcardaccount
# Insufficient funds.
# Addition Result : 4,6
# Multiplication Result : 2,4
# john - Manager : salary rs.95000
# alia - Developer : salary rs.70000
# bob - Designer : salary rs.75000
# animal.name : Mammal sound
# Lion :Mammal is eating
# Lion: Mammal is sleeping
# -----------------
# animal.name : Bird sound
# Parrot :Bird is eating
# ...
